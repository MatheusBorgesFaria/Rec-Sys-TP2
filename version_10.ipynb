# %% [markdown]
# # based-trees

# %% [markdown]
# Ideias:
# - FEITO: Usar a coluna para no texto
# - FEITO: Limpar os dados de conteudo
# - FEITO (lucas): ordenar os itens novos que ficaram por ultimo por popularidade
# - FEITO: Adicionar o nome da coluna, porque vai indicar o assunto, em conjunto do texto
#
# - tunar os hiperparametros
# - usa a imagem alem do texto
# - usar algum algoritmo mais simples apenas para usuarios novos, knn para content based
# - Entender o parametro exclude_unknowns=True do RatioSplit e se tem alguma forma do DMRL gerar previsoes para itens e usuarios novos
#
# - paralelizar a previsao
# Perguntas:

# %% [markdown]
# ## Imports

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import numpy as np
import pandas as pd
from tqdm import tqdm
from utils import load_data


# pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
np.set_printoptions(threshold=np.inf)

# %% [markdown]
# ## Load and process data

# %% [markdown]
# ### Load data

# %%
ratings, content, targets = load_data()

# %%
ratings["TimestampDate"] = ratings['Timestamp'].dt.date
ratings.loc[ratings.Rating == 0, "Rating"] = 0.01

# %% [markdown]
# ### Limpar os dados de conteudo
#
# - FEITO - Year: deletar o - no texto '2013–'
# - FEITO - Rated: alterar as diversas formas de escrever NA para NA. Esse e um caso especial
# - FEITO - alterar as diversas formas de escrever NA para None em todas as coluans
# - FEITO - Language: tem varias linhas que possuem bizarices como  'None, English' e 'None, French' , 'English, None'...
# - FEITO - Ratings: criar uma coluna para cada chave do dicionario, entender quais sao todas as chaves que existem
#
# -----------------------------------------------
# Variaveis que nao precisariam ser tratadas com um bert:
# - Metascore
# - imdbRating
# - Type

# %% [markdown]
# - Passar os scores para a mesma unidade de medida, talvez normalizar
# - otmizar o catboost, busca de hiperparametros
# - feature selection

# %%
content_auxiliar = content.drop(columns=["Poster", "Website", "Response", "Episode", "seriesID", "Season"]).copy()

# %%
content_auxiliar['Year'] = content_auxiliar['Year'].str.replace('–', '')

# %%
nan = content.totalSeasons.unique()[0]
dict_transform_to_na = {
    "Rated":['N/A', 'Not Rated', 'Unrated', 'UNRATED', 'NOT RATED'],
    "all": [nan, 'N/A', 'None', np.nan],
}

for na_value in dict_transform_to_na["all"]:
    content_auxiliar = content_auxiliar.replace(na_value, None)

for na_value in dict_transform_to_na["Rated"]:
    content_auxiliar['Rated'] = content_auxiliar['Rated'].replace(na_value, None)

# %%
content_auxiliar['Language'] = content_auxiliar['Language'].str.replace('None, ', '')
content_auxiliar['Language'] = content_auxiliar['Language'].str.replace(', None', '')

# %%
# Entendendo os valores possiveis para a coluna Ratings
# A coluna content_auxiliar.Ratings quarda uma lista que posde ter entre 0 e 3 dicionarios. Cada dicionario possui a chave 'Source', 'Value'.
num_ratings_per_item = []
unique_keys = []
rating_sources = []
rating_values = []

for rating_list in content_auxiliar.Ratings:
    num_ratings_per_item.append(len(rating_list))
    for rating_dict in rating_list:
        for key in rating_dict:
            unique_keys.append(key)
        rating_sources.append(rating_dict['Source'])
        rating_values.append(rating_dict['Value'])

set(rating_sources)
# Out:
# {'Internet Movie Database', 'Metacritic', 'Rotten Tomatoes'}

# %%
InternetMovieDatabase_list = []
Metacritic_list = []
RottenTomatoes_list = []
for rating_list in content_auxiliar.Ratings:
    InternetMovieDatabase_list.append(None)
    Metacritic_list.append(None)
    RottenTomatoes_list.append(None)
    for rating_dict in rating_list:
        if rating_dict['Source'] == 'Internet Movie Database':
            InternetMovieDatabase_list[-1] = rating_dict['Value']
        elif rating_dict['Source'] == 'Metacritic':
            Metacritic_list[-1] = rating_dict['Value']
        elif rating_dict['Source'] == 'Rotten Tomatoes':
            RottenTomatoes_list[-1] = rating_dict['Value']

# %%
content_auxiliar['Internet Movie Database'] = InternetMovieDatabase_list
content_auxiliar['Metacritic'] = Metacritic_list
content_auxiliar['Rotten Tomatoes'] = RottenTomatoes_list

# %%
content_auxiliar.drop(columns=['Ratings'], inplace=True)

# %% [markdown]
# ### Apendar a coluna no valor do dataframe

# %%
# content_columns = content_auxiliar.columns.to_list()
# content_columns.pop(0)

# %%
# for column in content_columns:
#     content_auxiliar[column] = content_auxiliar[column].apply(lambda x: f"{column}: {x}; " if x is not None else f"{column}: unknown value; ")

# %%
# content_processed = content_auxiliar[['ItemId']].copy()
# content_processed["text"] = content_auxiliar[content_columns].astype(str).fillna('').agg(' '.join, axis=1)

# %% [markdown]
# ### Viabiliza as colunas para um modelo tabular

# %%
content_auxiliar["Internet Movie Database"]
# Out:
# 0        5.5/10
# 1        6.9/10
# 2        7.5/10
# 3        4.2/10
# 4        6.7/10
#           ...
# 38007    6.2/10
# 38008    6.3/10
# 38009    7.2/10
# 38010      None
# 38011      None
# Name: Internet Movie Database, Length: 38012, dtype: object

# %%
content_auxiliar["Internet Movie Database"] = content_auxiliar["Internet Movie Database"].str.split("/").apply(lambda x: x[0] if x is not None else None)
content_auxiliar["Rotten Tomatoes"] = content_auxiliar["Rotten Tomatoes"].str.replace('%', "", regex=True)
content_auxiliar["Metacritic"] = content_auxiliar["Metacritic"].str.replace('/100', "", regex=True)
content_auxiliar["imdbVotes"] = content_auxiliar["imdbVotes"].str.replace(',', "", regex=True)

# %%
content_auxiliar["BoxOffice"].replace(',', "", regex=True, inplace=True)

# O metodo replace nao funcionnou para $, cuidado para nao rodar essa cedula 2 vezes
content_auxiliar["BoxOffice"] = content_auxiliar["BoxOffice"].apply(lambda x: x[1:] if x is not None else None) # troca valores $ por ""

# %%
content_auxiliar["Runtime"].replace(' min', "", regex=True, inplace=True)
mask = content_auxiliar.Runtime.str.contains('h', na=False)
content_auxiliar.loc[mask, "Runtime"] = content_auxiliar.loc[mask, "Runtime"].str.split("h").apply(lambda x: str(int(x[0]) * 60 + int(x[1])))

# %%
columns_to_float = ['Runtime', 'Internet Movie Database', 'Metacritic',
                    'Rotten Tomatoes', "imdbVotes", "BoxOffice",
                    "totalSeasons", "imdbRating", "Metascore"]  # Falta tartar Awards
content_auxiliar[columns_to_float] = content_auxiliar[columns_to_float].astype(float)

# %%
content_auxiliar["Internet Movie Database"]
# Out:
# 0        5.5
# 1        6.9
# 2        7.5
# 3        4.2
# 4        6.7
#         ...
# 38007    6.2
# 38008    6.3
# 38009    7.2
# 38010    NaN
# 38011    NaN
# Name: Internet Movie Database, Length: 38012, dtype: float64

# %%
variaveis_textos = ["Title", "Plot"]
variaveis_categoricas = ["Rated", "Director", "Production"] # variaveis para tratar "Language", Writer, Actors, Country
variaveis_data = ["Released", "Year", "DVD"] # Todas faltam tratar

# %%
content_auxiliar.drop(columns=columns_to_float+variaveis_textos+variaveis_categoricas).head(2)
# Out:
#        ItemId  Year     Released               Genre Writer    Actors  \
# 0  c9f0f895fb  1894  09 Jan 1894  Documentary, Short   None  Fred Ott
# 1  d3d9446802  1895  22 Mar 1895  Documentary, Short   None      None
#
#   Language        Country Awards   Type   DVD
# 0     None  United States  1 win  movie  None
# 1     None         France   None  movie  None

# %%
content_to_train = content_auxiliar[["ItemId"] + columns_to_float + variaveis_categoricas]

# %%
# transforma as colunas em numericas: Runtime

# usar o catboost para categoria e para suportar NA...
# transformar em categorias... Genre, Director, Writer, Actors, Language, Country, Type, Production

# Year transformar em anos ate 2025
# Released, DVD transformar em dias ate 2025

# %% [markdown]
# ## Train model

# %% [markdown]
# ### Lightfm

# %%
import dill

def save_object(obj, filename):
    with open(filename, 'wb') as file:
        dill.dump(obj, file)

def load_object(filename):
    with open(filename, 'rb') as file:
        return dill.load(file)

# %%
from lightfm.data import Dataset
from lightfm import LightFM

# %%
content_to_train[columns_to_float] = content_to_train[columns_to_float].fillna(-1)
content_to_train[variaveis_categoricas] = content_to_train[variaveis_categoricas].fillna("unknown")
# Out:
# /tmp/ipykernel_211666/2489804412.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   content_to_train[columns_to_float] = content_to_train[columns_to_float].fillna(-1)
# /tmp/ipykernel_211666/2489804412.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   content_to_train[variaveis_categoricas] = content_to_train[variaveis_categoricas].fillna("unknown")

# %%
dataset = Dataset()

# Include all unique item IDs from both ratings and content datasets
all_item_ids = list(set(ratings['ItemId'].unique()).union(content_auxiliar['ItemId'].unique()))
all_item_ids.sort()

# %%
content_to_train = content_to_train.sort_values("ItemId", ignore_index=True)

# Verifia se todos os itens estao iguais
content_to_train.ItemId.unique().tolist() == all_item_ids
# Out:
# True

# %%
item_features = set()
for index, row in content_to_train.drop(columns=["ItemId"]).iterrows():
    item_features.update(row.values)

# %%
# Fit the dataset with all user and item IDs
dataset.fit(users=ratings['UserId'].unique(),
            items=list(all_item_ids),
            item_features=item_features) # content_to_train.drop(columns="ItemId"))

# %%
features_columns = content_to_train.columns.to_list()
features_columns.pop(0)
item_features_data = []
for index, row in content_to_train.iterrows():
    item_features_data.append((row["ItemId"], row[features_columns].values.tolist()))

# %%
item_features_matrix = dataset.build_item_features(item_features_data, normalize=True)

# %%
(interactions, _) = dataset.build_interactions(
    [(row['UserId'], row['ItemId'], row['Rating']) for _, row in ratings.iterrows()]
)

# %%
from lightfm import LightFM
from os import cpu_count

# %%
# model = LightFM(loss='warp')
# model.fit(interactions, item_features=item_features_matrix, epochs=500, num_threads=cpu_count(), verbose=True)

# %%
model = load_object("LightFM_epochs=500.dill")

# %%
user_id_map, user_feature_map, item_id_map, item_feature_map = dataset.mapping()

# %%
train_data = ratings.merge(content_to_train, on="ItemId")

# %%
train_data["LightfmRating"] = model.predict(
    train_data.UserId.map(user_id_map.get).values,
    train_data.ItemId.map(item_id_map.get).values,
    item_features=item_features_matrix,
    num_threads=cpu_count())

# %%
target_prediction = targets.copy()
target_prediction["LightfmRating"] = model.predict(targets.UserId.map(user_id_map.get).values,
                                            targets.ItemId.map(item_id_map.get).values,
                                            item_features=item_features_matrix,
                                            num_threads=cpu_count())

# %%
target_prediction = target_prediction.merge(content_to_train, on="ItemId")

# %% [markdown]
# ### Catboost

# %%
from catboost import Pool, CatBoostRegressor

# %%
train_data.head(1)
# Out:
#        UserId      ItemId           Timestamp  Rating TimestampDate  Runtime  \
# 0  c4ca4238a0  91766eac45 2013-10-05 22:00:50     8.0    2013-10-05    108.0
#
#    Internet Movie Database  Metacritic  Rotten Tomatoes  imdbVotes  \
# 0                      5.8        49.0             43.0    78550.0
#
#     BoxOffice  totalSeasons  imdbRating  Metascore Rated         Director  \
# 0  60074103.0          -1.0         5.8       49.0     R  Roger Donaldson
#
#   Production  LightfmRating
# 0    unknown      -0.293552

# %%
features_columns = ["LightfmRating"] + columns_to_float + variaveis_categoricas
key_columns = ["UserId", "ItemId"]
target = "Rating"

# %%
train_data = train_data[features_columns + key_columns + [target]]
train_data = train_data.set_index(key_columns)
target_prediction = target_prediction[features_columns + key_columns]
target_prediction = target_prediction.set_index(key_columns)

# %%
model = CatBoostRegressor(
    iterations=10_000,
    task_type="GPU",    
    devices='0',
    cat_features=variaveis_categoricas

)

# %%
model.fit(train_data.drop(columns=target),
          train_data[target],
          verbose=True)
# Out:
# Learning rate set to 0.023914
# 0:	learn: 1.8512187	total: 32.7ms	remaining: 5m 27s
# 1:	learn: 1.8415059	total: 64ms	remaining: 5m 19s
# 2:	learn: 1.8321927	total: 92.4ms	remaining: 5m 7s
# 3:	learn: 1.8232735	total: 118ms	remaining: 4m 54s
# 4:	learn: 1.8147694	total: 153ms	remaining: 5m 4s
# 5:	learn: 1.8066218	total: 177ms	remaining: 4m 55s
# 6:	learn: 1.7987688	total: 206ms	remaining: 4m 54s
# 7:	learn: 1.7912712	total: 235ms	remaining: 4m 53s
# 8:	learn: 1.7839936	total: 266ms	remaining: 4m 55s
# 9:	learn: 1.7770321	total: 293ms	remaining: 4m 53s
# 10:	learn: 1.7702660	total: 322ms	remaining: 4m 52s
# 11:	learn: 1.7639259	total: 353ms	remaining: 4m 53s
# 12:	learn: 1.7576722	total: 383ms	remaining: 4m 53s
# 13:	learn: 1.7517792	total: 413ms	remaining: 4m 54s
# 14:	learn: 1.7461330	total: 442ms	remaining: 4m 54s
# 15:	learn: 1.7407264	total: 469ms	remaining: 4m 52s
# 16:	learn: 1.7354458	total: 500ms	remaining: 4m 53s
# 17:	learn: 1.7303809	total: 531ms	remaining: 4m 54s
# 18:	learn: 1.7256118	total: 558ms	remaining: 4m 53s
# 19:	learn: 1.7209980	total: 595ms	remaining: 4m 56s
# 20:	learn: 1.7165973	total: 630ms	remaining: 4m 59s
# 21:	learn: 1.7123219	total: 661ms	remaining: 5m
# 22:	learn: 1.7082521	total: 692ms	remaining: 5m
# 23:	learn: 1.7043497	total: 722ms	remaining: 5m
# 24:	learn: 1.7005554	total: 754ms	remaining: 5m 1s
# 25:	learn: 1.6969512	total: 786ms	remaining: 5m 1s
# 26:	learn: 1.6935036	total: 832ms	remaining: 5m 7s
# 27:	learn: 1.6902082	total: 865ms	remaining: 5m 7s
# 28:	learn: 1.6869716	total: 907ms	remaining: 5m 11s
# 29:	learn: 1.6838975	total: 944ms	remaining: 5m 13s
# 30:	learn: 1.6809787	total: 986ms	remaining: 5m 17s
# 31:	learn: 1.6782265	total: 1.02s	remaining: 5m 18s
# 32:	learn: 1.6755066	total: 1.05s	remaining: 5m 17s
# 33:	learn: 1.6728151	total: 1.09s	remaining: 5m 19s
# 34:	learn: 1.6702925	total: 1.12s	remaining: 5m 19s
# 35:	learn: 1.6677974	total: 1.15s	remaining: 5m 17s
# 36:	learn: 1.6654644	total: 1.18s	remaining: 5m 16s
# 37:	learn: 1.6632584	total: 1.21s	remaining: 5m 16s
# 38:	learn: 1.6611493	total: 1.23s	remaining: 5m 15s
# 39:	learn: 1.6591199	total: 1.26s	remaining: 5m 14s
# 40:	learn: 1.6571683	total: 1.29s	remaining: 5m 14s
# 41:	learn: 1.6552885	total: 1.32s	remaining: 5m 14s
# 42:	learn: 1.6534205	total: 1.36s	remaining: 5m 14s
# 43:	learn: 1.6516426	total: 1.39s	remaining: 5m 13s
# 44:	learn: 1.6500155	total: 1.42s	remaining: 5m 13s
# 45:	learn: 1.6484130	total: 1.45s	remaining: 5m 13s
# 46:	learn: 1.6468875	total: 1.48s	remaining: 5m 13s
# 47:	learn: 1.6453820	total: 1.51s	remaining: 5m 13s
# 48:	learn: 1.6438459	total: 1.54s	remaining: 5m 12s
# 49:	learn: 1.6424647	total: 1.57s	remaining: 5m 12s
# 50:	learn: 1.6411366	total: 1.6s	remaining: 5m 11s
# 51:	learn: 1.6398713	total: 1.62s	remaining: 5m 10s
# 52:	learn: 1.6386813	total: 1.66s	remaining: 5m 11s
# 53:	learn: 1.6375071	total: 1.69s	remaining: 5m 11s
# 54:	learn: 1.6363226	total: 1.73s	remaining: 5m 11s
# 55:	learn: 1.6352096	total: 1.75s	remaining: 5m 11s
# 56:	learn: 1.6341452	total: 1.79s	remaining: 5m 12s
# 57:	learn: 1.6331522	total: 1.83s	remaining: 5m 13s
# 58:	learn: 1.6321575	total: 1.86s	remaining: 5m 13s
# 59:	learn: 1.6312369	total: 1.89s	remaining: 5m 13s
# 60:	learn: 1.6303535	total: 1.93s	remaining: 5m 14s
# 61:	learn: 1.6294924	total: 1.96s	remaining: 5m 14s
# 62:	learn: 1.6286096	total: 2s	remaining: 5m 14s
# 63:	learn: 1.6278065	total: 2.03s	remaining: 5m 14s
# 64:	learn: 1.6270369	total: 2.05s	remaining: 5m 14s
# 65:	learn: 1.6262927	total: 2.09s	remaining: 5m 14s
# 66:	learn: 1.6255156	total: 2.12s	remaining: 5m 14s
# 67:	learn: 1.6247646	total: 2.16s	remaining: 5m 16s
# 68:	learn: 1.6239314	total: 2.2s	remaining: 5m 17s
# 69:	learn: 1.6232821	total: 2.23s	remaining: 5m 16s
# 70:	learn: 1.6226281	total: 2.26s	remaining: 5m 15s
# 71:	learn: 1.6219756	total: 2.29s	remaining: 5m 15s
# 72:	learn: 1.6213945	total: 2.32s	remaining: 5m 15s
# 73:	learn: 1.6208427	total: 2.35s	remaining: 5m 14s
# 74:	learn: 1.6203201	total: 2.38s	remaining: 5m 14s
# 75:	learn: 1.6196609	total: 2.41s	remaining: 5m 14s
# 76:	learn: 1.6190545	total: 2.44s	remaining: 5m 13s
# 77:	learn: 1.6185124	total: 2.46s	remaining: 5m 13s
# 78:	learn: 1.6180183	total: 2.49s	remaining: 5m 12s
# 79:	learn: 1.6175619	total: 2.52s	remaining: 5m 12s
# 80:	learn: 1.6171178	total: 2.55s	remaining: 5m 11s
# 81:	learn: 1.6166517	total: 2.65s	remaining: 5m 21s
# 82:	learn: 1.6162266	total: 2.83s	remaining: 5m 38s
# 83:	learn: 1.6158341	total: 3.01s	remaining: 5m 55s
# 84:	learn: 1.6154494	total: 3.21s	remaining: 6m 13s
# 85:	learn: 1.6150774	total: 3.38s	remaining: 6m 29s
# 86:	learn: 1.6145160	total: 3.55s	remaining: 6m 44s
# 87:	learn: 1.6141477	total: 3.58s	remaining: 6m 43s
# 88:	learn: 1.6137226	total: 3.61s	remaining: 6m 42s
# 89:	learn: 1.6133989	total: 3.64s	remaining: 6m 40s
# 90:	learn: 1.6130783	total: 3.67s	remaining: 6m 39s
# 91:	learn: 1.6127441	total: 3.7s	remaining: 6m 38s
# 92:	learn: 1.6123055	total: 3.74s	remaining: 6m 38s
# 93:	learn: 1.6120101	total: 3.78s	remaining: 6m 38s
# 94:	learn: 1.6117275	total: 3.81s	remaining: 6m 36s
# 95:	learn: 1.6114213	total: 3.84s	remaining: 6m 36s
# 96:	learn: 1.6111543	total: 3.87s	remaining: 6m 35s
# 97:	learn: 1.6109047	total: 3.9s	remaining: 6m 34s
# 98:	learn: 1.6106515	total: 3.93s	remaining: 6m 33s
# 99:	learn: 1.6102614	total: 3.98s	remaining: 6m 34s
# 100:	learn: 1.6100166	total: 4.01s	remaining: 6m 32s
# 101:	learn: 1.6097735	total: 4.04s	remaining: 6m 32s
# 102:	learn: 1.6095319	total: 4.07s	remaining: 6m 31s
# 103:	learn: 1.6093168	total: 4.11s	remaining: 6m 30s
# 104:	learn: 1.6089437	total: 4.15s	remaining: 6m 31s
# 105:	learn: 1.6087486	total: 4.18s	remaining: 6m 30s
# 106:	learn: 1.6085406	total: 4.21s	remaining: 6m 29s
# 107:	learn: 1.6081892	total: 4.25s	remaining: 6m 29s
# 108:	learn: 1.6078846	total: 4.29s	remaining: 6m 29s
# 109:	learn: 1.6075764	total: 4.33s	remaining: 6m 29s
# 110:	learn: 1.6073884	total: 4.36s	remaining: 6m 28s
# 111:	learn: 1.6072093	total: 4.39s	remaining: 6m 27s
# 112:	learn: 1.6068908	total: 4.43s	remaining: 6m 27s
# 113:	learn: 1.6067210	total: 4.46s	remaining: 6m 26s
# 114:	learn: 1.6065228	total: 4.49s	remaining: 6m 25s
# 115:	learn: 1.6063558	total: 4.51s	remaining: 6m 24s
# 116:	learn: 1.6061191	total: 4.55s	remaining: 6m 24s
# 117:	learn: 1.6059749	total: 4.57s	remaining: 6m 23s
# 118:	learn: 1.6058071	total: 4.6s	remaining: 6m 22s
# 119:	learn: 1.6055550	total: 4.63s	remaining: 6m 21s
# 120:	learn: 1.6054097	total: 4.66s	remaining: 6m 20s
# 121:	learn: 1.6052536	total: 4.69s	remaining: 6m 19s
# 122:	learn: 1.6051307	total: 4.72s	remaining: 6m 19s
# 123:	learn: 1.6048652	total: 4.76s	remaining: 6m 19s
# 124:	learn: 1.6046850	total: 4.8s	remaining: 6m 19s
# 125:	learn: 1.6045590	total: 4.84s	remaining: 6m 19s
# 126:	learn: 1.6043163	total: 4.87s	remaining: 6m 18s
# 127:	learn: 1.6041146	total: 4.9s	remaining: 6m 18s
# 128:	learn: 1.6039738	total: 4.94s	remaining: 6m 17s
# 129:	learn: 1.6038579	total: 4.97s	remaining: 6m 17s
# 130:	learn: 1.6036779	total: 5s	remaining: 6m 16s
# 131:	learn: 1.6035673	total: 5.04s	remaining: 6m 16s
# 132:	learn: 1.6034372	total: 5.06s	remaining: 6m 15s
# 133:	learn: 1.6032837	total: 5.1s	remaining: 6m 15s
# 134:	learn: 1.6031699	total: 5.14s	remaining: 6m 15s
# 135:	learn: 1.6030212	total: 5.18s	remaining: 6m 15s
# 136:	learn: 1.6029054	total: 5.21s	remaining: 6m 15s
# 137:	learn: 1.6027960	total: 5.24s	remaining: 6m 14s
# 138:	learn: 1.6026824	total: 5.27s	remaining: 6m 13s
# 139:	learn: 1.6025296	total: 5.3s	remaining: 6m 13s
# 140:	learn: 1.6024282	total: 5.33s	remaining: 6m 12s
# 141:	learn: 1.6023526	total: 5.36s	remaining: 6m 12s
# 142:	learn: 1.6022415	total: 5.39s	remaining: 6m 11s
# 143:	learn: 1.6021627	total: 5.42s	remaining: 6m 11s
# 144:	learn: 1.6020662	total: 5.46s	remaining: 6m 11s
# 145:	learn: 1.6018562	total: 5.5s	remaining: 6m 11s
# 146:	learn: 1.6017661	total: 5.53s	remaining: 6m 10s
# 147:	learn: 1.6016790	total: 5.56s	remaining: 6m 10s
# 148:	learn: 1.6015816	total: 5.6s	remaining: 6m 10s
# 149:	learn: 1.6013799	total: 5.64s	remaining: 6m 10s
# 150:	learn: 1.6013034	total: 5.67s	remaining: 6m 9s
# 151:	learn: 1.6012282	total: 5.7s	remaining: 6m 9s
# 152:	learn: 1.6011426	total: 5.73s	remaining: 6m 8s
# 153:	learn: 1.6010312	total: 5.76s	remaining: 6m 8s
# 154:	learn: 1.6009404	total: 5.8s	remaining: 6m 8s
# 155:	learn: 1.6008172	total: 5.85s	remaining: 6m 8s
# 156:	learn: 1.6006873	total: 5.88s	remaining: 6m 8s
# 157:	learn: 1.6005966	total: 5.91s	remaining: 6m 8s
# 158:	learn: 1.6005343	total: 5.95s	remaining: 6m 8s
# 159:	learn: 1.6004516	total: 6s	remaining: 6m 8s
# 160:	learn: 1.6003912	total: 6.04s	remaining: 6m 8s
# 161:	learn: 1.6003301	total: 6.08s	remaining: 6m 9s
# 162:	learn: 1.6002544	total: 6.11s	remaining: 6m 8s
# 163:	learn: 1.6001610	total: 6.15s	remaining: 6m 8s
# 164:	learn: 1.6000514	total: 6.17s	remaining: 6m 7s
# 165:	learn: 1.5998735	total: 6.22s	remaining: 6m 8s
# 166:	learn: 1.5998022	total: 6.26s	remaining: 6m 8s
# 167:	learn: 1.5997488	total: 6.29s	remaining: 6m 8s
# 168:	learn: 1.5996833	total: 6.32s	remaining: 6m 7s
# 169:	learn: 1.5995991	total: 6.36s	remaining: 6m 7s
# 170:	learn: 1.5995413	total: 6.4s	remaining: 6m 7s
# 171:	learn: 1.5994853	total: 6.44s	remaining: 6m 7s
# 172:	learn: 1.5993895	total: 6.47s	remaining: 6m 7s
# 173:	learn: 1.5993302	total: 6.5s	remaining: 6m 7s
# 174:	learn: 1.5992716	total: 6.54s	remaining: 6m 6s
# 175:	learn: 1.5992320	total: 6.57s	remaining: 6m 6s
# 176:	learn: 1.5991783	total: 6.6s	remaining: 6m 6s
# 177:	learn: 1.5991185	total: 6.64s	remaining: 6m 6s
# 178:	learn: 1.5989890	total: 6.68s	remaining: 6m 6s
# 179:	learn: 1.5989341	total: 6.72s	remaining: 6m 6s
# 180:	learn: 1.5988835	total: 6.76s	remaining: 6m 6s
# 181:	learn: 1.5988319	total: 6.79s	remaining: 6m 6s
# 182:	learn: 1.5987377	total: 6.83s	remaining: 6m 6s
# 183:	learn: 1.5986714	total: 6.87s	remaining: 6m 6s
# 184:	learn: 1.5985268	total: 6.91s	remaining: 6m 6s
# 185:	learn: 1.5984675	total: 6.94s	remaining: 6m 6s
# 186:	learn: 1.5984055	total: 6.98s	remaining: 6m 6s
# 187:	learn: 1.5983263	total: 7s	remaining: 6m 5s
# 188:	learn: 1.5982630	total: 7.03s	remaining: 6m 5s
# 189:	learn: 1.5982155	total: 7.07s	remaining: 6m 4s
# 190:	learn: 1.5981386	total: 7.09s	remaining: 6m 4s
# 191:	learn: 1.5980981	total: 7.13s	remaining: 6m 4s
# 192:	learn: 1.5980531	total: 7.16s	remaining: 6m 3s
# 193:	learn: 1.5980074	total: 7.2s	remaining: 6m 3s
# 194:	learn: 1.5979491	total: 7.23s	remaining: 6m 3s
# 195:	learn: 1.5979163	total: 7.26s	remaining: 6m 3s
# 196:	learn: 1.5978630	total: 7.29s	remaining: 6m 2s
# 197:	learn: 1.5978173	total: 7.32s	remaining: 6m 2s
# 198:	learn: 1.5977327	total: 7.35s	remaining: 6m 2s
# 199:	learn: 1.5976778	total: 7.38s	remaining: 6m 1s
# 200:	learn: 1.5976324	total: 7.41s	remaining: 6m 1s
# 201:	learn: 1.5975766	total: 7.44s	remaining: 6m
# 202:	learn: 1.5975225	total: 7.46s	remaining: 6m
# 203:	learn: 1.5974206	total: 7.49s	remaining: 5m 59s
# 204:	learn: 1.5973805	total: 7.53s	remaining: 5m 59s
# 205:	learn: 1.5973397	total: 7.56s	remaining: 5m 59s
# 206:	learn: 1.5972833	total: 7.59s	remaining: 5m 59s
# 207:	learn: 1.5972227	total: 7.62s	remaining: 5m 58s
# 208:	learn: 1.5971642	total: 7.66s	remaining: 5m 58s
# 209:	learn: 1.5970559	total: 7.7s	remaining: 5m 59s
# 210:	learn: 1.5969693	total: 7.73s	remaining: 5m 58s
# 211:	learn: 1.5969205	total: 7.77s	remaining: 5m 58s
# 212:	learn: 1.5968681	total: 7.8s	remaining: 5m 58s
# 213:	learn: 1.5968234	total: 7.84s	remaining: 5m 58s
# 214:	learn: 1.5967504	total: 7.88s	remaining: 5m 58s
# 215:	learn: 1.5967186	total: 7.92s	remaining: 5m 58s
# 216:	learn: 1.5966459	total: 7.96s	remaining: 5m 58s
# 217:	learn: 1.5965821	total: 8s	remaining: 5m 58s
# 218:	learn: 1.5965167	total: 8.04s	remaining: 5m 58s
# 219:	learn: 1.5964716	total: 8.06s	remaining: 5m 58s
# 220:	learn: 1.5964389	total: 8.09s	remaining: 5m 58s
# 221:	learn: 1.5963840	total: 8.13s	remaining: 5m 58s
# 222:	learn: 1.5963120	total: 8.16s	remaining: 5m 57s
# 223:	learn: 1.5962753	total: 8.19s	remaining: 5m 57s
# 224:	learn: 1.5962335	total: 8.23s	remaining: 5m 57s
# 225:	learn: 1.5961973	total: 8.26s	remaining: 5m 57s
# 226:	learn: 1.5961494	total: 8.29s	remaining: 5m 57s
# 227:	learn: 1.5961044	total: 8.32s	remaining: 5m 56s
# 228:	learn: 1.5960765	total: 8.35s	remaining: 5m 56s
# 229:	learn: 1.5960450	total: 8.39s	remaining: 5m 56s
# 230:	learn: 1.5960175	total: 8.42s	remaining: 5m 56s
# 231:	learn: 1.5959193	total: 8.46s	remaining: 5m 56s
# 232:	learn: 1.5958761	total: 8.49s	remaining: 5m 55s
# 233:	learn: 1.5957579	total: 8.53s	remaining: 5m 55s
# 234:	learn: 1.5957146	total: 8.57s	remaining: 5m 56s
# 235:	learn: 1.5956678	total: 8.61s	remaining: 5m 56s
# 236:	learn: 1.5956319	total: 8.63s	remaining: 5m 55s
# 237:	learn: 1.5955417	total: 8.67s	remaining: 5m 55s
# 238:	learn: 1.5955049	total: 8.7s	remaining: 5m 55s
# 239:	learn: 1.5954634	total: 8.73s	remaining: 5m 54s
# 240:	learn: 1.5954307	total: 8.76s	remaining: 5m 54s
# 241:	learn: 1.5953893	total: 8.8s	remaining: 5m 54s
# 242:	learn: 1.5953574	total: 8.83s	remaining: 5m 54s
# 243:	learn: 1.5952601	total: 8.87s	remaining: 5m 54s
# 244:	learn: 1.5952245	total: 8.9s	remaining: 5m 54s
# 245:	learn: 1.5951951	total: 8.93s	remaining: 5m 54s
# 246:	learn: 1.5951515	total: 8.97s	remaining: 5m 54s
# 247:	learn: 1.5950850	total: 9.01s	remaining: 5m 54s
# 248:	learn: 1.5950587	total: 9.05s	remaining: 5m 54s
# 249:	learn: 1.5950089	total: 9.09s	remaining: 5m 54s
# 250:	learn: 1.5949289	total: 9.13s	remaining: 5m 54s
# 251:	learn: 1.5948476	total: 9.17s	remaining: 5m 54s
# 252:	learn: 1.5948218	total: 9.2s	remaining: 5m 54s
# 253:	learn: 1.5947946	total: 9.23s	remaining: 5m 54s
# 254:	learn: 1.5947605	total: 9.26s	remaining: 5m 53s
# 255:	learn: 1.5947312	total: 9.29s	remaining: 5m 53s
# 256:	learn: 1.5946603	total: 9.33s	remaining: 5m 53s
# 257:	learn: 1.5946378	total: 9.36s	remaining: 5m 53s
# 258:	learn: 1.5946149	total: 9.39s	remaining: 5m 53s
# 259:	learn: 1.5945575	total: 9.43s	remaining: 5m 53s
# 260:	learn: 1.5944862	total: 9.46s	remaining: 5m 53s
# 261:	learn: 1.5944486	total: 9.49s	remaining: 5m 52s
# 262:	learn: 1.5944268	total: 9.53s	remaining: 5m 52s
# 263:	learn: 1.5943953	total: 9.56s	remaining: 5m 52s
# 264:	learn: 1.5943760	total: 9.59s	remaining: 5m 52s
# 265:	learn: 1.5943548	total: 9.63s	remaining: 5m 52s
# 266:	learn: 1.5942796	total: 9.66s	remaining: 5m 52s
# 267:	learn: 1.5942471	total: 9.69s	remaining: 5m 51s
# 268:	learn: 1.5941839	total: 9.72s	remaining: 5m 51s
# 269:	learn: 1.5941452	total: 9.76s	remaining: 5m 51s
# 270:	learn: 1.5940781	total: 9.79s	remaining: 5m 51s
# 271:	learn: 1.5940423	total: 9.82s	remaining: 5m 51s
# 272:	learn: 1.5940231	total: 9.85s	remaining: 5m 51s
# 273:	learn: 1.5939754	total: 9.89s	remaining: 5m 50s
# 274:	learn: 1.5939487	total: 9.92s	remaining: 5m 50s
# 275:	learn: 1.5939238	total: 9.94s	remaining: 5m 50s
# 276:	learn: 1.5938571	total: 9.98s	remaining: 5m 50s
# 277:	learn: 1.5938047	total: 10s	remaining: 5m 50s
# 278:	learn: 1.5937864	total: 10.1s	remaining: 5m 50s
# 279:	learn: 1.5937519	total: 10.1s	remaining: 5m 50s
# 280:	learn: 1.5937320	total: 10.1s	remaining: 5m 49s
# 281:	learn: 1.5936958	total: 10.1s	remaining: 5m 49s
# 282:	learn: 1.5936431	total: 10.2s	remaining: 5m 49s
# 283:	learn: 1.5935940	total: 10.2s	remaining: 5m 49s
# 284:	learn: 1.5935706	total: 10.3s	remaining: 5m 49s
# 285:	learn: 1.5935562	total: 10.3s	remaining: 5m 49s
# 286:	learn: 1.5935177	total: 10.3s	remaining: 5m 49s
# 287:	learn: 1.5934872	total: 10.4s	remaining: 5m 49s
# 288:	learn: 1.5934530	total: 10.4s	remaining: 5m 48s
# 289:	learn: 1.5934388	total: 10.4s	remaining: 5m 48s
# 290:	learn: 1.5934176	total: 10.4s	remaining: 5m 48s
# 291:	learn: 1.5933836	total: 10.5s	remaining: 5m 48s
# 292:	learn: 1.5933521	total: 10.5s	remaining: 5m 48s
# 293:	learn: 1.5933268	total: 10.5s	remaining: 5m 48s
# 294:	learn: 1.5932917	total: 10.6s	remaining: 5m 48s
# 295:	learn: 1.5932630	total: 10.6s	remaining: 5m 48s
# 296:	learn: 1.5932053	total: 10.7s	remaining: 5m 48s
# 297:	learn: 1.5931742	total: 10.7s	remaining: 5m 48s
# 298:	learn: 1.5931467	total: 10.8s	remaining: 5m 51s
# 299:	learn: 1.5931172	total: 11s	remaining: 5m 56s
# 300:	learn: 1.5930971	total: 11.3s	remaining: 6m 2s
# 301:	learn: 1.5930660	total: 11.5s	remaining: 6m 9s
# 302:	learn: 1.5930465	total: 11.7s	remaining: 6m 14s
# 303:	learn: 1.5930163	total: 11.7s	remaining: 6m 14s
# 304:	learn: 1.5929796	total: 11.8s	remaining: 6m 14s
# 305:	learn: 1.5929708	total: 11.8s	remaining: 6m 14s
# 306:	learn: 1.5929501	total: 11.8s	remaining: 6m 13s
# 307:	learn: 1.5929253	total: 11.9s	remaining: 6m 13s
# 308:	learn: 1.5928812	total: 11.9s	remaining: 6m 13s
# 309:	learn: 1.5928645	total: 11.9s	remaining: 6m 13s
# 310:	learn: 1.5928163	total: 12s	remaining: 6m 13s
# 311:	learn: 1.5927965	total: 12s	remaining: 6m 12s
# 312:	learn: 1.5927551	total: 12s	remaining: 6m 12s
# 313:	learn: 1.5927405	total: 12.1s	remaining: 6m 12s
# 314:	learn: 1.5927269	total: 12.1s	remaining: 6m 12s
# 315:	learn: 1.5926988	total: 12.1s	remaining: 6m 12s
# 316:	learn: 1.5926809	total: 12.2s	remaining: 6m 12s
# 317:	learn: 1.5926487	total: 12.2s	remaining: 6m 11s
# 318:	learn: 1.5926218	total: 12.3s	remaining: 6m 11s
# 319:	learn: 1.5925780	total: 12.3s	remaining: 6m 11s
# 320:	learn: 1.5925516	total: 12.3s	remaining: 6m 11s
# 321:	learn: 1.5925316	total: 12.4s	remaining: 6m 11s
# 322:	learn: 1.5924895	total: 12.4s	remaining: 6m 11s
# 323:	learn: 1.5924429	total: 12.4s	remaining: 6m 11s
# 324:	learn: 1.5924121	total: 12.5s	remaining: 6m 11s
# 325:	learn: 1.5923780	total: 12.5s	remaining: 6m 11s
# 326:	learn: 1.5923266	total: 12.6s	remaining: 6m 11s
# 327:	learn: 1.5922834	total: 12.6s	remaining: 6m 11s
# 328:	learn: 1.5922574	total: 12.6s	remaining: 6m 10s
# 329:	learn: 1.5922442	total: 12.7s	remaining: 6m 10s
# 330:	learn: 1.5922228	total: 12.7s	remaining: 6m 10s
# 331:	learn: 1.5921835	total: 12.7s	remaining: 6m 10s
# 332:	learn: 1.5921646	total: 12.8s	remaining: 6m 10s
# 333:	learn: 1.5921450	total: 12.8s	remaining: 6m 10s
# 334:	learn: 1.5921069	total: 12.8s	remaining: 6m 10s
# 335:	learn: 1.5920790	total: 12.9s	remaining: 6m 10s
# 336:	learn: 1.5920563	total: 12.9s	remaining: 6m 9s
# 337:	learn: 1.5920404	total: 12.9s	remaining: 6m 9s
# 338:	learn: 1.5920187	total: 13s	remaining: 6m 9s
# 339:	learn: 1.5919979	total: 13s	remaining: 6m 9s
# 340:	learn: 1.5919867	total: 13s	remaining: 6m 9s
# 341:	learn: 1.5919453	total: 13.1s	remaining: 6m 9s
# 342:	learn: 1.5919190	total: 13.1s	remaining: 6m 9s
# 343:	learn: 1.5918962	total: 13.2s	remaining: 6m 9s
# 344:	learn: 1.5918809	total: 13.2s	remaining: 6m 9s
# 345:	learn: 1.5918186	total: 13.2s	remaining: 6m 9s
# 346:	learn: 1.5917895	total: 13.3s	remaining: 6m 8s
# 347:	learn: 1.5917531	total: 13.3s	remaining: 6m 8s
# 348:	learn: 1.5917293	total: 13.3s	remaining: 6m 8s
# 349:	learn: 1.5917034	total: 13.4s	remaining: 6m 8s
# 350:	learn: 1.5916775	total: 13.4s	remaining: 6m 8s
# 351:	learn: 1.5916485	total: 13.4s	remaining: 6m 8s
# 352:	learn: 1.5916235	total: 13.5s	remaining: 6m 8s
# 353:	learn: 1.5916132	total: 13.5s	remaining: 6m 7s
# 354:	learn: 1.5915700	total: 13.5s	remaining: 6m 7s
# 355:	learn: 1.5915310	total: 13.6s	remaining: 6m 7s
# 356:	learn: 1.5915149	total: 13.6s	remaining: 6m 7s
# 357:	learn: 1.5914876	total: 13.6s	remaining: 6m 7s
# 358:	learn: 1.5914671	total: 13.7s	remaining: 6m 7s
# 359:	learn: 1.5914493	total: 13.7s	remaining: 6m 7s
# 360:	learn: 1.5914367	total: 13.8s	remaining: 6m 7s
# 361:	learn: 1.5914129	total: 13.8s	remaining: 6m 7s
# 362:	learn: 1.5913774	total: 13.8s	remaining: 6m 7s
# 363:	learn: 1.5913441	total: 13.9s	remaining: 6m 6s
# 364:	learn: 1.5913040	total: 13.9s	remaining: 6m 6s
# 365:	learn: 1.5912850	total: 13.9s	remaining: 6m 6s
# 366:	learn: 1.5912682	total: 14s	remaining: 6m 6s
# 367:	learn: 1.5912570	total: 14s	remaining: 6m 6s
# 368:	learn: 1.5912175	total: 14s	remaining: 6m 6s
# 369:	learn: 1.5911866	total: 14.1s	remaining: 6m 6s
# 370:	learn: 1.5911769	total: 14.1s	remaining: 6m 6s
# 371:	learn: 1.5911423	total: 14.1s	remaining: 6m 5s
# 372:	learn: 1.5911210	total: 14.2s	remaining: 6m 5s
# 373:	learn: 1.5910949	total: 14.2s	remaining: 6m 5s
# 374:	learn: 1.5910752	total: 14.2s	remaining: 6m 5s
# 375:	learn: 1.5910654	total: 14.3s	remaining: 6m 5s
# 376:	learn: 1.5910536	total: 14.3s	remaining: 6m 5s
# 377:	learn: 1.5910072	total: 14.3s	remaining: 6m 5s
# 378:	learn: 1.5909886	total: 14.4s	remaining: 6m 5s
# 379:	learn: 1.5909695	total: 14.4s	remaining: 6m 4s
# 380:	learn: 1.5909638	total: 14.4s	remaining: 6m 4s
# 381:	learn: 1.5909536	total: 14.5s	remaining: 6m 4s
# 382:	learn: 1.5909415	total: 14.5s	remaining: 6m 4s
# 383:	learn: 1.5909235	total: 14.5s	remaining: 6m 4s
# 384:	learn: 1.5909072	total: 14.6s	remaining: 6m 3s
# 385:	learn: 1.5908869	total: 14.6s	remaining: 6m 3s
# 386:	learn: 1.5908662	total: 14.6s	remaining: 6m 3s
# 387:	learn: 1.5908289	total: 14.7s	remaining: 6m 3s
# 388:	learn: 1.5908117	total: 14.7s	remaining: 6m 3s
# 389:	learn: 1.5907935	total: 14.7s	remaining: 6m 2s
# 390:	learn: 1.5907681	total: 14.8s	remaining: 6m 2s
# 391:	learn: 1.5907559	total: 14.8s	remaining: 6m 2s
# 392:	learn: 1.5907415	total: 14.8s	remaining: 6m 2s
# 393:	learn: 1.5907187	total: 14.9s	remaining: 6m 2s
# 394:	learn: 1.5906839	total: 14.9s	remaining: 6m 2s
# 395:	learn: 1.5906666	total: 14.9s	remaining: 6m 1s
# 396:	learn: 1.5906411	total: 15s	remaining: 6m 1s
# 397:	learn: 1.5905889	total: 15s	remaining: 6m 1s
# 398:	learn: 1.5905561	total: 15s	remaining: 6m 1s
# 399:	learn: 1.5905393	total: 15.1s	remaining: 6m 1s
# 400:	learn: 1.5905268	total: 15.1s	remaining: 6m 1s
# 401:	learn: 1.5904726	total: 15.1s	remaining: 6m 1s
# 402:	learn: 1.5904550	total: 15.2s	remaining: 6m 1s
# 403:	learn: 1.5904378	total: 15.2s	remaining: 6m
# 404:	learn: 1.5904094	total: 15.2s	remaining: 6m
# 405:	learn: 1.5903952	total: 15.3s	remaining: 6m
# 406:	learn: 1.5903790	total: 15.3s	remaining: 6m
# 407:	learn: 1.5903621	total: 15.3s	remaining: 6m
# 408:	learn: 1.5903464	total: 15.4s	remaining: 6m
# 409:	learn: 1.5903153	total: 15.4s	remaining: 6m
# 410:	learn: 1.5902894	total: 15.4s	remaining: 5m 59s
# 411:	learn: 1.5902691	total: 15.5s	remaining: 5m 59s
# 412:	learn: 1.5902471	total: 15.5s	remaining: 5m 59s
# 413:	learn: 1.5902079	total: 15.5s	remaining: 5m 59s
# 414:	learn: 1.5901965	total: 15.6s	remaining: 5m 59s
# 415:	learn: 1.5901857	total: 15.6s	remaining: 5m 59s
# 416:	learn: 1.5901456	total: 15.6s	remaining: 5m 59s
# 417:	learn: 1.5901363	total: 15.7s	remaining: 5m 59s
# 418:	learn: 1.5901271	total: 15.7s	remaining: 5m 58s
# 419:	learn: 1.5901084	total: 15.7s	remaining: 5m 58s
# 420:	learn: 1.5900832	total: 15.8s	remaining: 5m 58s
# 421:	learn: 1.5900670	total: 15.8s	remaining: 5m 58s
# 422:	learn: 1.5900436	total: 15.8s	remaining: 5m 58s
# 423:	learn: 1.5900191	total: 15.9s	remaining: 5m 58s
# 424:	learn: 1.5900158	total: 15.9s	remaining: 5m 57s
# 425:	learn: 1.5899995	total: 15.9s	remaining: 5m 57s
# 426:	learn: 1.5899850	total: 15.9s	remaining: 5m 57s
# 427:	learn: 1.5899652	total: 16s	remaining: 5m 57s
# 428:	learn: 1.5899529	total: 16s	remaining: 5m 57s
# 429:	learn: 1.5899371	total: 16.1s	remaining: 5m 57s
# 430:	learn: 1.5899128	total: 16.1s	remaining: 5m 57s
# 431:	learn: 1.5899000	total: 16.1s	remaining: 5m 57s
# 432:	learn: 1.5898780	total: 16.2s	remaining: 5m 57s
# 433:	learn: 1.5898697	total: 16.2s	remaining: 5m 57s
# 434:	learn: 1.5898494	total: 16.2s	remaining: 5m 56s
# 435:	learn: 1.5898149	total: 16.3s	remaining: 5m 56s
# 436:	learn: 1.5898018	total: 16.3s	remaining: 5m 56s
# 437:	learn: 1.5897815	total: 16.3s	remaining: 5m 56s
# 438:	learn: 1.5897736	total: 16.4s	remaining: 5m 56s
# 439:	learn: 1.5897665	total: 16.4s	remaining: 5m 55s
# 440:	learn: 1.5897410	total: 16.4s	remaining: 5m 55s
# 441:	learn: 1.5897210	total: 16.4s	remaining: 5m 55s
# 442:	learn: 1.5897009	total: 16.5s	remaining: 5m 55s
# 443:	learn: 1.5896866	total: 16.5s	remaining: 5m 55s
# 444:	learn: 1.5896689	total: 16.5s	remaining: 5m 55s
# 445:	learn: 1.5896555	total: 16.6s	remaining: 5m 55s
# 446:	learn: 1.5896400	total: 16.6s	remaining: 5m 54s
# 447:	learn: 1.5896239	total: 16.6s	remaining: 5m 54s
# 448:	learn: 1.5895959	total: 16.7s	remaining: 5m 54s
# 449:	learn: 1.5895856	total: 16.7s	remaining: 5m 54s
# 450:	learn: 1.5895621	total: 16.7s	remaining: 5m 54s
# 451:	learn: 1.5895493	total: 16.8s	remaining: 5m 54s
# 452:	learn: 1.5895349	total: 16.8s	remaining: 5m 53s
# 453:	learn: 1.5895138	total: 16.8s	remaining: 5m 53s
# 454:	learn: 1.5894904	total: 16.9s	remaining: 5m 53s
# 455:	learn: 1.5894753	total: 16.9s	remaining: 5m 53s
# 456:	learn: 1.5894533	total: 16.9s	remaining: 5m 53s
# 457:	learn: 1.5894365	total: 17s	remaining: 5m 53s
# 458:	learn: 1.5894174	total: 17s	remaining: 5m 53s
# 459:	learn: 1.5893924	total: 17s	remaining: 5m 53s
# 460:	learn: 1.5893803	total: 17.1s	remaining: 5m 53s
# 461:	learn: 1.5893649	total: 17.1s	remaining: 5m 52s
# 462:	learn: 1.5893478	total: 17.1s	remaining: 5m 52s
# 463:	learn: 1.5893428	total: 17.2s	remaining: 5m 52s
# 464:	learn: 1.5893279	total: 17.2s	remaining: 5m 52s
# 465:	learn: 1.5893198	total: 17.2s	remaining: 5m 52s
# 466:	learn: 1.5893062	total: 17.3s	remaining: 5m 52s
# 467:	learn: 1.5892901	total: 17.3s	remaining: 5m 52s
# 468:	learn: 1.5892864	total: 17.3s	remaining: 5m 52s
# 469:	learn: 1.5892739	total: 17.4s	remaining: 5m 52s
# 470:	learn: 1.5892398	total: 17.4s	remaining: 5m 51s
# 471:	learn: 1.5892309	total: 17.4s	remaining: 5m 51s
# 472:	learn: 1.5892091	total: 17.5s	remaining: 5m 51s
# 473:	learn: 1.5892019	total: 17.5s	remaining: 5m 51s
# 474:	learn: 1.5891944	total: 17.5s	remaining: 5m 51s
# 475:	learn: 1.5891803	total: 17.6s	remaining: 5m 51s
# 476:	learn: 1.5891645	total: 17.6s	remaining: 5m 51s
# 477:	learn: 1.5891502	total: 17.6s	remaining: 5m 51s
# 478:	learn: 1.5891273	total: 17.7s	remaining: 5m 50s
# 479:	learn: 1.5891152	total: 17.7s	remaining: 5m 50s
# 480:	learn: 1.5891067	total: 17.7s	remaining: 5m 50s
# 481:	learn: 1.5890968	total: 17.8s	remaining: 5m 50s
# 482:	learn: 1.5890867	total: 17.8s	remaining: 5m 50s
# 483:	learn: 1.5890682	total: 17.8s	remaining: 5m 50s
# 484:	learn: 1.5890609	total: 17.8s	remaining: 5m 49s
# 485:	learn: 1.5890569	total: 17.9s	remaining: 5m 49s
# 486:	learn: 1.5890261	total: 17.9s	remaining: 5m 49s
# 487:	learn: 1.5890126	total: 17.9s	remaining: 5m 49s
# 488:	learn: 1.5889972	total: 18s	remaining: 5m 49s
# 489:	learn: 1.5889905	total: 18s	remaining: 5m 49s
# 490:	learn: 1.5889599	total: 18s	remaining: 5m 49s
# 491:	learn: 1.5889335	total: 18.1s	remaining: 5m 49s
# 492:	learn: 1.5889190	total: 18.1s	remaining: 5m 49s
# 493:	learn: 1.5889103	total: 18.1s	remaining: 5m 49s
# 494:	learn: 1.5888948	total: 18.2s	remaining: 5m 49s
# 495:	learn: 1.5888627	total: 18.2s	remaining: 5m 49s
# 496:	learn: 1.5888504	total: 18.2s	remaining: 5m 48s
# 497:	learn: 1.5888265	total: 18.3s	remaining: 5m 48s
# 498:	learn: 1.5888121	total: 18.3s	remaining: 5m 48s
# 499:	learn: 1.5887924	total: 18.4s	remaining: 5m 48s
# 500:	learn: 1.5887748	total: 18.4s	remaining: 5m 48s
# 501:	learn: 1.5887687	total: 18.4s	remaining: 5m 48s
# 502:	learn: 1.5887572	total: 18.5s	remaining: 5m 48s
# 503:	learn: 1.5887510	total: 18.5s	remaining: 5m 48s
# 504:	learn: 1.5887320	total: 18.5s	remaining: 5m 48s
# 505:	learn: 1.5887306	total: 18.6s	remaining: 5m 48s
# 506:	learn: 1.5887166	total: 18.6s	remaining: 5m 48s
# 507:	learn: 1.5886982	total: 18.6s	remaining: 5m 48s
# 508:	learn: 1.5886854	total: 18.7s	remaining: 5m 48s
# 509:	learn: 1.5886796	total: 18.7s	remaining: 5m 48s
# 510:	learn: 1.5886629	total: 18.7s	remaining: 5m 47s
# 511:	learn: 1.5886429	total: 18.8s	remaining: 5m 47s
# 512:	learn: 1.5886353	total: 18.8s	remaining: 5m 47s
# 513:	learn: 1.5886124	total: 18.8s	remaining: 5m 47s
# 514:	learn: 1.5886057	total: 18.9s	remaining: 5m 47s
# 515:	learn: 1.5885941	total: 18.9s	remaining: 5m 47s
# 516:	learn: 1.5885813	total: 18.9s	remaining: 5m 47s
# 517:	learn: 1.5885691	total: 19s	remaining: 5m 47s
# 518:	learn: 1.5885588	total: 19s	remaining: 5m 47s
# 519:	learn: 1.5885412	total: 19s	remaining: 5m 47s
# 520:	learn: 1.5885245	total: 19.1s	remaining: 5m 47s
# 521:	learn: 1.5885147	total: 19.1s	remaining: 5m 46s
# 522:	learn: 1.5884904	total: 19.1s	remaining: 5m 46s
# 523:	learn: 1.5884764	total: 19.2s	remaining: 5m 46s
# 524:	learn: 1.5884553	total: 19.2s	remaining: 5m 46s
# 525:	learn: 1.5884391	total: 19.2s	remaining: 5m 46s
# 526:	learn: 1.5884136	total: 19.3s	remaining: 5m 46s
# 527:	learn: 1.5883916	total: 19.3s	remaining: 5m 46s
# 528:	learn: 1.5883780	total: 19.3s	remaining: 5m 46s
# 529:	learn: 1.5883508	total: 19.4s	remaining: 5m 46s
# 530:	learn: 1.5883368	total: 19.4s	remaining: 5m 46s
# 531:	learn: 1.5883116	total: 19.4s	remaining: 5m 45s
# 532:	learn: 1.5883090	total: 19.5s	remaining: 5m 45s
# 533:	learn: 1.5883023	total: 19.5s	remaining: 5m 45s
# 534:	learn: 1.5882930	total: 19.5s	remaining: 5m 45s
# 535:	learn: 1.5882724	total: 19.6s	remaining: 5m 45s
# 536:	learn: 1.5882608	total: 19.6s	remaining: 5m 45s
# 537:	learn: 1.5882502	total: 19.7s	remaining: 5m 45s
# 538:	learn: 1.5882383	total: 19.7s	remaining: 5m 45s
# 539:	learn: 1.5882229	total: 19.7s	remaining: 5m 45s
# 540:	learn: 1.5882079	total: 19.8s	remaining: 5m 45s
# 541:	learn: 1.5881923	total: 19.8s	remaining: 5m 45s
# 542:	learn: 1.5881780	total: 19.8s	remaining: 5m 45s
# 543:	learn: 1.5881588	total: 19.9s	remaining: 5m 45s
# 544:	learn: 1.5881447	total: 19.9s	remaining: 5m 45s
# 545:	learn: 1.5881168	total: 20s	remaining: 5m 45s
# 546:	learn: 1.5881079	total: 20s	remaining: 5m 45s
# 547:	learn: 1.5880875	total: 20s	remaining: 5m 45s
# 548:	learn: 1.5880753	total: 20.1s	remaining: 5m 45s
# 549:	learn: 1.5880548	total: 20.1s	remaining: 5m 45s
# 550:	learn: 1.5880457	total: 20.1s	remaining: 5m 44s
# 551:	learn: 1.5880309	total: 20.2s	remaining: 5m 44s
# 552:	learn: 1.5880160	total: 20.2s	remaining: 5m 44s
# 553:	learn: 1.5880054	total: 20.2s	remaining: 5m 44s
# 554:	learn: 1.5879888	total: 20.2s	remaining: 5m 44s
# 555:	learn: 1.5879829	total: 20.3s	remaining: 5m 44s
# 556:	learn: 1.5879706	total: 20.3s	remaining: 5m 44s
# 557:	learn: 1.5879433	total: 20.3s	remaining: 5m 44s
# 558:	learn: 1.5879228	total: 20.4s	remaining: 5m 44s
# 559:	learn: 1.5879049	total: 20.4s	remaining: 5m 43s
# 560:	learn: 1.5878892	total: 20.4s	remaining: 5m 43s
# 561:	learn: 1.5878703	total: 20.5s	remaining: 5m 43s
# 562:	learn: 1.5878644	total: 20.5s	remaining: 5m 43s
# 563:	learn: 1.5878572	total: 20.5s	remaining: 5m 43s
# 564:	learn: 1.5878431	total: 20.6s	remaining: 5m 43s
# 565:	learn: 1.5878219	total: 20.6s	remaining: 5m 43s
# 566:	learn: 1.5878005	total: 20.6s	remaining: 5m 43s
# 567:	learn: 1.5877886	total: 20.6s	remaining: 5m 42s
# 568:	learn: 1.5877658	total: 20.7s	remaining: 5m 42s
# 569:	learn: 1.5877599	total: 20.7s	remaining: 5m 42s
# 570:	learn: 1.5877487	total: 20.7s	remaining: 5m 42s
# 571:	learn: 1.5877281	total: 20.8s	remaining: 5m 42s
# 572:	learn: 1.5877212	total: 20.8s	remaining: 5m 42s
# 573:	learn: 1.5877107	total: 20.8s	remaining: 5m 42s
# 574:	learn: 1.5876964	total: 20.9s	remaining: 5m 42s
# 575:	learn: 1.5876848	total: 20.9s	remaining: 5m 42s
# 576:	learn: 1.5876689	total: 21s	remaining: 5m 42s
# 577:	learn: 1.5876423	total: 21s	remaining: 5m 42s
# 578:	learn: 1.5876363	total: 21s	remaining: 5m 41s
# 579:	learn: 1.5876277	total: 21s	remaining: 5m 41s
# 580:	learn: 1.5876155	total: 21.1s	remaining: 5m 41s
# 581:	learn: 1.5876023	total: 21.1s	remaining: 5m 41s
# 582:	learn: 1.5875859	total: 21.1s	remaining: 5m 41s
# 583:	learn: 1.5875683	total: 21.2s	remaining: 5m 41s
# 584:	learn: 1.5875605	total: 21.2s	remaining: 5m 41s
# 585:	learn: 1.5875475	total: 21.2s	remaining: 5m 41s
# 586:	learn: 1.5875396	total: 21.3s	remaining: 5m 41s
# 587:	learn: 1.5875309	total: 21.3s	remaining: 5m 40s
# 588:	learn: 1.5875195	total: 21.3s	remaining: 5m 40s
# 589:	learn: 1.5875021	total: 21.4s	remaining: 5m 40s
# 590:	learn: 1.5874865	total: 21.4s	remaining: 5m 40s
# 591:	learn: 1.5874834	total: 21.4s	remaining: 5m 40s
# 592:	learn: 1.5874635	total: 21.5s	remaining: 5m 40s
# 593:	learn: 1.5874507	total: 21.5s	remaining: 5m 40s
# 594:	learn: 1.5874391	total: 21.5s	remaining: 5m 40s
# 595:	learn: 1.5874286	total: 21.6s	remaining: 5m 40s
# 596:	learn: 1.5874261	total: 21.6s	remaining: 5m 40s
# 597:	learn: 1.5874126	total: 21.6s	remaining: 5m 39s
# 598:	learn: 1.5874003	total: 21.7s	remaining: 5m 39s
# 599:	learn: 1.5873860	total: 21.7s	remaining: 5m 39s
# 600:	learn: 1.5873562	total: 21.7s	remaining: 5m 39s
# 601:	learn: 1.5873434	total: 21.8s	remaining: 5m 39s
# 602:	learn: 1.5873394	total: 21.8s	remaining: 5m 39s
# 603:	learn: 1.5873316	total: 21.8s	remaining: 5m 39s
# 604:	learn: 1.5873211	total: 21.9s	remaining: 5m 39s
# 605:	learn: 1.5873133	total: 21.9s	remaining: 5m 39s
# 606:	learn: 1.5873087	total: 21.9s	remaining: 5m 39s
# 607:	learn: 1.5873007	total: 22s	remaining: 5m 39s
# 608:	learn: 1.5872881	total: 22s	remaining: 5m 39s
# 609:	learn: 1.5872734	total: 22s	remaining: 5m 38s
# 610:	learn: 1.5872613	total: 22.1s	remaining: 5m 38s
# 611:	learn: 1.5872487	total: 22.1s	remaining: 5m 38s
# 612:	learn: 1.5872423	total: 22.1s	remaining: 5m 38s
# 613:	learn: 1.5872313	total: 22.1s	remaining: 5m 38s
# 614:	learn: 1.5872202	total: 22.2s	remaining: 5m 38s
# 615:	learn: 1.5872029	total: 22.2s	remaining: 5m 38s
# 616:	learn: 1.5871890	total: 22.2s	remaining: 5m 38s
# 617:	learn: 1.5871835	total: 22.3s	remaining: 5m 38s
# 618:	learn: 1.5871744	total: 22.3s	remaining: 5m 37s
# 619:	learn: 1.5871650	total: 22.3s	remaining: 5m 37s
# 620:	learn: 1.5871498	total: 22.4s	remaining: 5m 37s
# 621:	learn: 1.5871386	total: 22.4s	remaining: 5m 37s
# 622:	learn: 1.5871199	total: 22.4s	remaining: 5m 37s
# 623:	learn: 1.5871101	total: 22.5s	remaining: 5m 37s
# 624:	learn: 1.5870986	total: 22.5s	remaining: 5m 37s
# 625:	learn: 1.5870961	total: 22.5s	remaining: 5m 37s
# 626:	learn: 1.5870888	total: 22.5s	remaining: 5m 36s
# 627:	learn: 1.5870746	total: 22.6s	remaining: 5m 36s
# 628:	learn: 1.5870570	total: 22.6s	remaining: 5m 36s
# 629:	learn: 1.5870484	total: 22.6s	remaining: 5m 36s
# 630:	learn: 1.5870405	total: 22.7s	remaining: 5m 36s
# 631:	learn: 1.5870294	total: 22.7s	remaining: 5m 36s
# 632:	learn: 1.5870134	total: 22.7s	remaining: 5m 36s
# 633:	learn: 1.5870025	total: 22.8s	remaining: 5m 36s
# 634:	learn: 1.5869841	total: 22.8s	remaining: 5m 36s
# 635:	learn: 1.5869729	total: 22.8s	remaining: 5m 36s
# 636:	learn: 1.5869607	total: 22.9s	remaining: 5m 36s
# 637:	learn: 1.5869462	total: 22.9s	remaining: 5m 35s
# 638:	learn: 1.5869369	total: 22.9s	remaining: 5m 35s
# 639:	learn: 1.5869210	total: 23s	remaining: 5m 35s
# 640:	learn: 1.5869178	total: 23s	remaining: 5m 35s
# 641:	learn: 1.5869056	total: 23s	remaining: 5m 35s
# 642:	learn: 1.5868912	total: 23.1s	remaining: 5m 35s
# 643:	learn: 1.5868811	total: 23.1s	remaining: 5m 35s
# 644:	learn: 1.5868708	total: 23.1s	remaining: 5m 35s
# 645:	learn: 1.5868606	total: 23.1s	remaining: 5m 35s
# 646:	learn: 1.5868542	total: 23.2s	remaining: 5m 34s
# 647:	learn: 1.5868490	total: 23.2s	remaining: 5m 34s
# 648:	learn: 1.5868397	total: 23.2s	remaining: 5m 34s
# 649:	learn: 1.5868368	total: 23.3s	remaining: 5m 34s
# 650:	learn: 1.5868248	total: 23.3s	remaining: 5m 34s
# 651:	learn: 1.5868158	total: 23.3s	remaining: 5m 34s
# 652:	learn: 1.5867952	total: 23.4s	remaining: 5m 34s
# 653:	learn: 1.5867848	total: 23.4s	remaining: 5m 34s
# 654:	learn: 1.5867726	total: 23.4s	remaining: 5m 34s
# 655:	learn: 1.5867684	total: 23.5s	remaining: 5m 34s
# 656:	learn: 1.5867634	total: 23.5s	remaining: 5m 34s
# 657:	learn: 1.5867533	total: 23.6s	remaining: 5m 34s
# 658:	learn: 1.5867322	total: 23.6s	remaining: 5m 34s
# 659:	learn: 1.5867194	total: 23.6s	remaining: 5m 34s
# 660:	learn: 1.5867120	total: 23.6s	remaining: 5m 33s
# 661:	learn: 1.5867028	total: 23.7s	remaining: 5m 33s
# 662:	learn: 1.5866929	total: 23.7s	remaining: 5m 33s
# 663:	learn: 1.5866856	total: 23.7s	remaining: 5m 33s
# 664:	learn: 1.5866739	total: 23.8s	remaining: 5m 33s
# 665:	learn: 1.5866723	total: 23.8s	remaining: 5m 33s
# 666:	learn: 1.5866505	total: 23.8s	remaining: 5m 33s
# 667:	learn: 1.5866401	total: 23.9s	remaining: 5m 33s
# 668:	learn: 1.5866288	total: 23.9s	remaining: 5m 33s
# 669:	learn: 1.5866245	total: 23.9s	remaining: 5m 33s
# 670:	learn: 1.5866171	total: 24s	remaining: 5m 33s
# 671:	learn: 1.5866098	total: 24s	remaining: 5m 33s
# 672:	learn: 1.5866028	total: 24.1s	remaining: 5m 33s
# 673:	learn: 1.5865938	total: 24.1s	remaining: 5m 33s
# 674:	learn: 1.5865808	total: 24.1s	remaining: 5m 33s
# 675:	learn: 1.5865691	total: 24.2s	remaining: 5m 33s
# 676:	learn: 1.5865509	total: 24.2s	remaining: 5m 33s
# 677:	learn: 1.5865389	total: 24.2s	remaining: 5m 33s
# 678:	learn: 1.5865226	total: 24.3s	remaining: 5m 32s
# 679:	learn: 1.5865144	total: 24.3s	remaining: 5m 32s
# 680:	learn: 1.5864802	total: 24.3s	remaining: 5m 32s
# 681:	learn: 1.5864698	total: 24.4s	remaining: 5m 32s
# 682:	learn: 1.5864572	total: 24.4s	remaining: 5m 32s
# 683:	learn: 1.5864468	total: 24.4s	remaining: 5m 32s
# 684:	learn: 1.5864310	total: 24.5s	remaining: 5m 32s
# 685:	learn: 1.5864173	total: 24.5s	remaining: 5m 32s
# 686:	learn: 1.5864031	total: 24.5s	remaining: 5m 32s
# 687:	learn: 1.5863922	total: 24.6s	remaining: 5m 32s
# 688:	learn: 1.5863754	total: 24.6s	remaining: 5m 32s
# 689:	learn: 1.5863571	total: 24.6s	remaining: 5m 32s
# 690:	learn: 1.5863401	total: 24.7s	remaining: 5m 32s
# 691:	learn: 1.5863319	total: 24.7s	remaining: 5m 32s
# 692:	learn: 1.5863105	total: 24.7s	remaining: 5m 32s
# 693:	learn: 1.5863009	total: 24.8s	remaining: 5m 32s
# 694:	learn: 1.5862877	total: 24.8s	remaining: 5m 32s
# 695:	learn: 1.5862797	total: 24.8s	remaining: 5m 31s
# 696:	learn: 1.5862625	total: 24.9s	remaining: 5m 31s
# 697:	learn: 1.5862514	total: 24.9s	remaining: 5m 31s
# 698:	learn: 1.5862407	total: 24.9s	remaining: 5m 31s
# 699:	learn: 1.5862354	total: 25s	remaining: 5m 31s
# 700:	learn: 1.5862221	total: 25s	remaining: 5m 31s
# 701:	learn: 1.5862135	total: 25s	remaining: 5m 31s
# 702:	learn: 1.5862026	total: 25.1s	remaining: 5m 31s
# 703:	learn: 1.5861811	total: 25.1s	remaining: 5m 31s
# 704:	learn: 1.5861703	total: 25.1s	remaining: 5m 31s
# 705:	learn: 1.5861567	total: 25.2s	remaining: 5m 31s
# 706:	learn: 1.5861396	total: 25.2s	remaining: 5m 31s
# 707:	learn: 1.5861240	total: 25.2s	remaining: 5m 31s
# 708:	learn: 1.5861161	total: 25.3s	remaining: 5m 30s
# 709:	learn: 1.5861107	total: 25.3s	remaining: 5m 30s
# 710:	learn: 1.5861009	total: 25.3s	remaining: 5m 30s
# 711:	learn: 1.5860937	total: 25.4s	remaining: 5m 30s
# 712:	learn: 1.5860890	total: 25.4s	remaining: 5m 30s
# 713:	learn: 1.5860819	total: 25.4s	remaining: 5m 30s
# 714:	learn: 1.5860752	total: 25.5s	remaining: 5m 30s
# 715:	learn: 1.5860682	total: 25.5s	remaining: 5m 30s
# 716:	learn: 1.5860571	total: 25.5s	remaining: 5m 30s
# 717:	learn: 1.5860472	total: 25.6s	remaining: 5m 30s
# 718:	learn: 1.5860321	total: 25.6s	remaining: 5m 30s
# 719:	learn: 1.5860276	total: 25.6s	remaining: 5m 30s
# 720:	learn: 1.5860164	total: 25.6s	remaining: 5m 29s
# 721:	learn: 1.5860073	total: 25.7s	remaining: 5m 29s
# 722:	learn: 1.5860016	total: 25.7s	remaining: 5m 29s
# 723:	learn: 1.5859939	total: 25.7s	remaining: 5m 29s
# 724:	learn: 1.5859892	total: 25.8s	remaining: 5m 29s
# 725:	learn: 1.5859782	total: 25.8s	remaining: 5m 29s
# 726:	learn: 1.5859639	total: 25.8s	remaining: 5m 29s
# 727:	learn: 1.5859420	total: 25.9s	remaining: 5m 29s
# 728:	learn: 1.5859291	total: 25.9s	remaining: 5m 29s
# 729:	learn: 1.5859224	total: 25.9s	remaining: 5m 29s
# 730:	learn: 1.5859110	total: 26s	remaining: 5m 29s
# 731:	learn: 1.5858997	total: 26s	remaining: 5m 29s
# 732:	learn: 1.5858874	total: 26s	remaining: 5m 28s
# 733:	learn: 1.5858727	total: 26.1s	remaining: 5m 28s
# 734:	learn: 1.5858592	total: 26.1s	remaining: 5m 28s
# 735:	learn: 1.5858509	total: 26.1s	remaining: 5m 28s
# 736:	learn: 1.5858288	total: 26.1s	remaining: 5m 28s
# 737:	learn: 1.5858221	total: 26.2s	remaining: 5m 28s
# 738:	learn: 1.5858086	total: 26.2s	remaining: 5m 28s
# 739:	learn: 1.5858000	total: 26.2s	remaining: 5m 28s
# 740:	learn: 1.5857927	total: 26.3s	remaining: 5m 28s
# 741:	learn: 1.5857892	total: 26.3s	remaining: 5m 27s
# 742:	learn: 1.5857789	total: 26.3s	remaining: 5m 27s
# 743:	learn: 1.5857638	total: 26.4s	remaining: 5m 27s
# 744:	learn: 1.5857573	total: 26.4s	remaining: 5m 27s
# 745:	learn: 1.5857463	total: 26.4s	remaining: 5m 27s
# 746:	learn: 1.5857404	total: 26.4s	remaining: 5m 27s
# 747:	learn: 1.5857220	total: 26.5s	remaining: 5m 27s
# 748:	learn: 1.5857173	total: 26.5s	remaining: 5m 27s
# 749:	learn: 1.5857062	total: 26.5s	remaining: 5m 27s
# 750:	learn: 1.5856954	total: 26.6s	remaining: 5m 27s
# 751:	learn: 1.5856844	total: 26.6s	remaining: 5m 27s
# 752:	learn: 1.5856804	total: 26.7s	remaining: 5m 27s
# 753:	learn: 1.5856742	total: 26.7s	remaining: 5m 27s
# 754:	learn: 1.5856651	total: 26.7s	remaining: 5m 27s
# 755:	learn: 1.5856626	total: 26.7s	remaining: 5m 27s
# 756:	learn: 1.5856521	total: 26.8s	remaining: 5m 26s
# 757:	learn: 1.5856429	total: 26.8s	remaining: 5m 26s
# 758:	learn: 1.5856313	total: 26.8s	remaining: 5m 26s
# 759:	learn: 1.5856236	total: 26.9s	remaining: 5m 26s
# 760:	learn: 1.5856181	total: 26.9s	remaining: 5m 26s
# 761:	learn: 1.5856078	total: 26.9s	remaining: 5m 26s
# 762:	learn: 1.5856034	total: 26.9s	remaining: 5m 26s
# 763:	learn: 1.5855959	total: 27s	remaining: 5m 26s
# 764:	learn: 1.5855940	total: 27s	remaining: 5m 26s
# 765:	learn: 1.5855810	total: 27.1s	remaining: 5m 26s
# 766:	learn: 1.5855724	total: 27.1s	remaining: 5m 26s
# 767:	learn: 1.5855621	total: 27.1s	remaining: 5m 25s
# 768:	learn: 1.5855519	total: 27.1s	remaining: 5m 25s
# 769:	learn: 1.5855443	total: 27.2s	remaining: 5m 25s
# 770:	learn: 1.5855308	total: 27.2s	remaining: 5m 25s
# 771:	learn: 1.5855142	total: 27.2s	remaining: 5m 25s
# 772:	learn: 1.5855092	total: 27.3s	remaining: 5m 25s
# 773:	learn: 1.5854934	total: 27.3s	remaining: 5m 25s
# 774:	learn: 1.5854827	total: 27.3s	remaining: 5m 25s
# 775:	learn: 1.5854723	total: 27.4s	remaining: 5m 25s
# 776:	learn: 1.5854601	total: 27.4s	remaining: 5m 25s
# 777:	learn: 1.5854546	total: 27.4s	remaining: 5m 25s
# 778:	learn: 1.5854411	total: 27.5s	remaining: 5m 25s
# 779:	learn: 1.5854375	total: 27.5s	remaining: 5m 24s
# 780:	learn: 1.5854240	total: 27.5s	remaining: 5m 24s
# 781:	learn: 1.5854144	total: 27.6s	remaining: 5m 24s
# 782:	learn: 1.5854020	total: 27.6s	remaining: 5m 24s
# 783:	learn: 1.5853917	total: 27.6s	remaining: 5m 24s
# 784:	learn: 1.5853866	total: 27.7s	remaining: 5m 24s
# 785:	learn: 1.5853842	total: 27.7s	remaining: 5m 24s
# 786:	learn: 1.5853668	total: 27.7s	remaining: 5m 24s
# 787:	learn: 1.5853595	total: 27.8s	remaining: 5m 24s
# 788:	learn: 1.5853514	total: 27.8s	remaining: 5m 24s
# 789:	learn: 1.5853422	total: 27.8s	remaining: 5m 24s
# 790:	learn: 1.5853281	total: 27.9s	remaining: 5m 24s
# 791:	learn: 1.5853226	total: 27.9s	remaining: 5m 24s
# 792:	learn: 1.5853140	total: 27.9s	remaining: 5m 24s
# 793:	learn: 1.5853048	total: 28s	remaining: 5m 24s
# 794:	learn: 1.5853002	total: 28s	remaining: 5m 24s
# 795:	learn: 1.5852956	total: 28s	remaining: 5m 24s
# 796:	learn: 1.5852899	total: 28.1s	remaining: 5m 24s
# 797:	learn: 1.5852824	total: 28.1s	remaining: 5m 23s
# 798:	learn: 1.5852773	total: 28.1s	remaining: 5m 23s
# 799:	learn: 1.5852749	total: 28.1s	remaining: 5m 23s
# 800:	learn: 1.5852614	total: 28.2s	remaining: 5m 23s
# 801:	learn: 1.5852564	total: 28.2s	remaining: 5m 23s
# 802:	learn: 1.5852480	total: 28.2s	remaining: 5m 23s
# 803:	learn: 1.5852457	total: 28.3s	remaining: 5m 23s
# 804:	learn: 1.5852418	total: 28.3s	remaining: 5m 23s
# 805:	learn: 1.5852329	total: 28.3s	remaining: 5m 23s
# 806:	learn: 1.5852281	total: 28.4s	remaining: 5m 23s
# 807:	learn: 1.5852204	total: 28.4s	remaining: 5m 23s
# 808:	learn: 1.5852178	total: 28.4s	remaining: 5m 23s
# 809:	learn: 1.5852035	total: 28.5s	remaining: 5m 23s
# 810:	learn: 1.5851892	total: 28.5s	remaining: 5m 22s
# 811:	learn: 1.5851858	total: 28.5s	remaining: 5m 22s
# 812:	learn: 1.5851747	total: 28.6s	remaining: 5m 22s
# 813:	learn: 1.5851637	total: 28.6s	remaining: 5m 22s
# 814:	learn: 1.5851616	total: 28.6s	remaining: 5m 22s
# 815:	learn: 1.5851507	total: 28.7s	remaining: 5m 22s
# 816:	learn: 1.5851409	total: 28.7s	remaining: 5m 22s
# 817:	learn: 1.5851247	total: 28.7s	remaining: 5m 22s
# 818:	learn: 1.5851093	total: 28.8s	remaining: 5m 22s
# 819:	learn: 1.5851055	total: 28.8s	remaining: 5m 22s
# 820:	learn: 1.5850933	total: 28.8s	remaining: 5m 22s
# 821:	learn: 1.5850801	total: 28.8s	remaining: 5m 22s
# 822:	learn: 1.5850711	total: 28.9s	remaining: 5m 22s
# 823:	learn: 1.5850603	total: 28.9s	remaining: 5m 22s
# 824:	learn: 1.5850527	total: 28.9s	remaining: 5m 21s
# 825:	learn: 1.5850348	total: 29s	remaining: 5m 21s
# 826:	learn: 1.5850244	total: 29s	remaining: 5m 21s
# 827:	learn: 1.5850176	total: 29s	remaining: 5m 21s
# 828:	learn: 1.5850085	total: 29.1s	remaining: 5m 21s
# 829:	learn: 1.5850040	total: 29.1s	remaining: 5m 21s
# 830:	learn: 1.5849911	total: 29.2s	remaining: 5m 21s
# 831:	learn: 1.5849792	total: 29.2s	remaining: 5m 21s
# 832:	learn: 1.5849733	total: 29.2s	remaining: 5m 21s
# 833:	learn: 1.5849611	total: 29.3s	remaining: 5m 21s
# 834:	learn: 1.5849501	total: 29.3s	remaining: 5m 21s
# 835:	learn: 1.5849412	total: 29.3s	remaining: 5m 21s
# 836:	learn: 1.5849368	total: 29.4s	remaining: 5m 21s
# 837:	learn: 1.5849326	total: 29.4s	remaining: 5m 21s
# 838:	learn: 1.5849294	total: 29.4s	remaining: 5m 21s
# 839:	learn: 1.5849232	total: 29.5s	remaining: 5m 21s
# 840:	learn: 1.5849140	total: 29.5s	remaining: 5m 21s
# 841:	learn: 1.5849016	total: 29.5s	remaining: 5m 21s
# 842:	learn: 1.5848918	total: 29.6s	remaining: 5m 21s
# 843:	learn: 1.5848882	total: 29.6s	remaining: 5m 21s
# 844:	learn: 1.5848788	total: 29.6s	remaining: 5m 21s
# 845:	learn: 1.5848664	total: 29.7s	remaining: 5m 21s
# 846:	learn: 1.5848634	total: 29.7s	remaining: 5m 21s
# 847:	learn: 1.5848578	total: 29.7s	remaining: 5m 20s
# 848:	learn: 1.5848543	total: 29.8s	remaining: 5m 20s
# 849:	learn: 1.5848448	total: 29.8s	remaining: 5m 20s
# 850:	learn: 1.5848355	total: 29.8s	remaining: 5m 20s
# 851:	learn: 1.5848316	total: 29.9s	remaining: 5m 20s
# 852:	learn: 1.5848272	total: 29.9s	remaining: 5m 20s
# 853:	learn: 1.5848195	total: 29.9s	remaining: 5m 20s
# 854:	learn: 1.5848165	total: 30s	remaining: 5m 20s
# 855:	learn: 1.5848089	total: 30s	remaining: 5m 20s
# 856:	learn: 1.5848068	total: 30s	remaining: 5m 20s
# 857:	learn: 1.5847986	total: 30.1s	remaining: 5m 20s
# 858:	learn: 1.5847792	total: 30.1s	remaining: 5m 20s
# 859:	learn: 1.5847757	total: 30.2s	remaining: 5m 20s
# 860:	learn: 1.5847647	total: 30.2s	remaining: 5m 20s
# 861:	learn: 1.5847538	total: 30.2s	remaining: 5m 20s
# 862:	learn: 1.5847501	total: 30.3s	remaining: 5m 20s
# 863:	learn: 1.5847389	total: 30.3s	remaining: 5m 20s
# 864:	learn: 1.5847346	total: 30.3s	remaining: 5m 20s
# 865:	learn: 1.5847257	total: 30.4s	remaining: 5m 20s
# 866:	learn: 1.5847182	total: 30.4s	remaining: 5m 20s
# 867:	learn: 1.5847106	total: 30.4s	remaining: 5m 19s
# 868:	learn: 1.5846970	total: 30.4s	remaining: 5m 19s
# 869:	learn: 1.5846870	total: 30.5s	remaining: 5m 19s
# 870:	learn: 1.5846821	total: 30.5s	remaining: 5m 19s
# 871:	learn: 1.5846744	total: 30.6s	remaining: 5m 19s
# 872:	learn: 1.5846607	total: 30.6s	remaining: 5m 19s
# 873:	learn: 1.5846565	total: 30.6s	remaining: 5m 19s
# 874:	learn: 1.5846467	total: 30.7s	remaining: 5m 19s
# 875:	learn: 1.5846439	total: 30.7s	remaining: 5m 19s
# 876:	learn: 1.5846368	total: 30.7s	remaining: 5m 19s
# 877:	learn: 1.5846231	total: 30.8s	remaining: 5m 19s
# 878:	learn: 1.5846167	total: 30.8s	remaining: 5m 19s
# 879:	learn: 1.5846109	total: 30.8s	remaining: 5m 19s
# 880:	learn: 1.5846024	total: 30.9s	remaining: 5m 19s
# 881:	learn: 1.5845942	total: 30.9s	remaining: 5m 19s
# 882:	learn: 1.5845849	total: 30.9s	remaining: 5m 19s
# 883:	learn: 1.5845797	total: 31s	remaining: 5m 19s
# 884:	learn: 1.5845724	total: 31s	remaining: 5m 19s
# 885:	learn: 1.5845632	total: 31.1s	remaining: 5m 19s
# 886:	learn: 1.5845499	total: 31.1s	remaining: 5m 19s
# 887:	learn: 1.5845449	total: 31.1s	remaining: 5m 19s
# 888:	learn: 1.5845366	total: 31.2s	remaining: 5m 19s
# 889:	learn: 1.5845264	total: 31.2s	remaining: 5m 19s
# 890:	learn: 1.5845233	total: 31.2s	remaining: 5m 19s
# 891:	learn: 1.5845144	total: 31.3s	remaining: 5m 19s
# 892:	learn: 1.5845052	total: 31.3s	remaining: 5m 19s
# 893:	learn: 1.5844975	total: 31.3s	remaining: 5m 19s
# 894:	learn: 1.5844927	total: 31.4s	remaining: 5m 19s
# 895:	learn: 1.5844780	total: 31.4s	remaining: 5m 19s
# 896:	learn: 1.5844735	total: 31.4s	remaining: 5m 19s
# 897:	learn: 1.5844708	total: 31.5s	remaining: 5m 19s
# 898:	learn: 1.5844601	total: 31.5s	remaining: 5m 19s
# 899:	learn: 1.5844438	total: 31.6s	remaining: 5m 19s
# 900:	learn: 1.5844310	total: 31.6s	remaining: 5m 18s
# 901:	learn: 1.5844238	total: 31.6s	remaining: 5m 18s
# 902:	learn: 1.5844165	total: 31.6s	remaining: 5m 18s
# 903:	learn: 1.5844128	total: 31.7s	remaining: 5m 18s
# 904:	learn: 1.5844015	total: 31.7s	remaining: 5m 18s
# 905:	learn: 1.5843930	total: 31.8s	remaining: 5m 18s
# 906:	learn: 1.5843882	total: 31.8s	remaining: 5m 18s
# 907:	learn: 1.5843816	total: 31.8s	remaining: 5m 18s
# 908:	learn: 1.5843798	total: 31.9s	remaining: 5m 18s
# 909:	learn: 1.5843710	total: 31.9s	remaining: 5m 18s
# 910:	learn: 1.5843605	total: 31.9s	remaining: 5m 18s
# 911:	learn: 1.5843561	total: 32s	remaining: 5m 18s
# 912:	learn: 1.5843489	total: 32s	remaining: 5m 18s
# ...
# 9701:	learn: 1.5625025	total: 8m 58s	remaining: 16.5s
# 9702:	learn: 1.5625013	total: 8m 58s	remaining: 16.5s
# 9703:	learn: 1.5625005	total: 8m 58s	remaining: 16.4s
# 9704:	learn: 1.5624981	total: 8m 58s	remaining: 16.4s
# 9705:	learn: 1.5624957	total: 8m 58s	remaining: 16.3s
# 9706:	learn: 1.5624948	total: 8m 58s	remaining: 16.3s
# 9707:	learn: 1.5624910	total: 8m 59s	remaining: 16.2s
# 9708:	learn: 1.5624886	total: 8m 59s	remaining: 16.2s
# 9709:	learn: 1.5624868	total: 8m 59s	remaining: 16.1s
# 9710:	learn: 1.5624850	total: 8m 59s	remaining: 16s
# 9711:	learn: 1.5624830	total: 8m 59s	remaining: 16s
# 9712:	learn: 1.5624825	total: 8m 59s	remaining: 15.9s
# 9713:	learn: 1.5624813	total: 8m 59s	remaining: 15.9s
# 9714:	learn: 1.5624801	total: 8m 59s	remaining: 15.8s
# 9715:	learn: 1.5624782	total: 8m 59s	remaining: 15.8s
# 9716:	learn: 1.5624751	total: 8m 59s	remaining: 15.7s
# 9717:	learn: 1.5624739	total: 8m 59s	remaining: 15.7s
# 9718:	learn: 1.5624709	total: 8m 59s	remaining: 15.6s
# 9719:	learn: 1.5624688	total: 9m	remaining: 15.6s
# 9720:	learn: 1.5624678	total: 9m	remaining: 15.5s
# 9721:	learn: 1.5624670	total: 9m	remaining: 15.5s
# 9722:	learn: 1.5624661	total: 9m	remaining: 15.4s
# 9723:	learn: 1.5624654	total: 9m	remaining: 15.3s
# 9724:	learn: 1.5624640	total: 9m	remaining: 15.3s
# 9725:	learn: 1.5624634	total: 9m 1s	remaining: 15.2s
# 9726:	learn: 1.5624620	total: 9m 1s	remaining: 15.2s
# 9727:	learn: 1.5624591	total: 9m 1s	remaining: 15.1s
# 9728:	learn: 1.5624584	total: 9m 1s	remaining: 15.1s
# 9729:	learn: 1.5624567	total: 9m 1s	remaining: 15s
# 9730:	learn: 1.5624555	total: 9m 1s	remaining: 15s
# 9731:	learn: 1.5624549	total: 9m 1s	remaining: 14.9s
# 9732:	learn: 1.5624548	total: 9m 1s	remaining: 14.9s
# 9733:	learn: 1.5624524	total: 9m 1s	remaining: 14.8s
# 9734:	learn: 1.5624511	total: 9m 1s	remaining: 14.7s
# 9735:	learn: 1.5624463	total: 9m 1s	remaining: 14.7s
# 9736:	learn: 1.5624448	total: 9m 1s	remaining: 14.6s
# 9737:	learn: 1.5624444	total: 9m 1s	remaining: 14.6s
# 9738:	learn: 1.5624428	total: 9m 2s	remaining: 14.5s
# 9739:	learn: 1.5624415	total: 9m 2s	remaining: 14.5s
# 9740:	learn: 1.5624389	total: 9m 2s	remaining: 14.4s
# 9741:	learn: 1.5624362	total: 9m 2s	remaining: 14.4s
# 9742:	learn: 1.5624347	total: 9m 2s	remaining: 14.3s
# 9743:	learn: 1.5624335	total: 9m 2s	remaining: 14.2s
# 9744:	learn: 1.5624324	total: 9m 2s	remaining: 14.2s
# 9745:	learn: 1.5624297	total: 9m 2s	remaining: 14.1s
# 9746:	learn: 1.5624282	total: 9m 2s	remaining: 14.1s
# 9747:	learn: 1.5624270	total: 9m 2s	remaining: 14s
# 9748:	learn: 1.5624260	total: 9m 2s	remaining: 14s
# 9749:	learn: 1.5624242	total: 9m 2s	remaining: 13.9s
# 9750:	learn: 1.5624212	total: 9m 3s	remaining: 13.9s
# 9751:	learn: 1.5624195	total: 9m 3s	remaining: 13.8s
# 9752:	learn: 1.5624162	total: 9m 3s	remaining: 13.8s
# 9753:	learn: 1.5624147	total: 9m 3s	remaining: 13.7s
# 9754:	learn: 1.5624127	total: 9m 3s	remaining: 13.7s
# 9755:	learn: 1.5624115	total: 9m 4s	remaining: 13.6s
# 9756:	learn: 1.5624094	total: 9m 4s	remaining: 13.6s
# 9757:	learn: 1.5624085	total: 9m 4s	remaining: 13.5s
# 9758:	learn: 1.5624077	total: 9m 4s	remaining: 13.4s
# 9759:	learn: 1.5624065	total: 9m 4s	remaining: 13.4s
# 9760:	learn: 1.5624059	total: 9m 4s	remaining: 13.3s
# 9761:	learn: 1.5624036	total: 9m 4s	remaining: 13.3s
# 9762:	learn: 1.5624024	total: 9m 4s	remaining: 13.2s
# 9763:	learn: 1.5624015	total: 9m 4s	remaining: 13.2s
# 9764:	learn: 1.5624008	total: 9m 4s	remaining: 13.1s
# 9765:	learn: 1.5623978	total: 9m 4s	remaining: 13.1s
# 9766:	learn: 1.5623965	total: 9m 4s	remaining: 13s
# 9767:	learn: 1.5623962	total: 9m 5s	remaining: 12.9s
# 9768:	learn: 1.5623927	total: 9m 5s	remaining: 12.9s
# 9769:	learn: 1.5623916	total: 9m 5s	remaining: 12.8s
# 9770:	learn: 1.5623895	total: 9m 5s	remaining: 12.8s
# 9771:	learn: 1.5623877	total: 9m 5s	remaining: 12.7s
# 9772:	learn: 1.5623868	total: 9m 5s	remaining: 12.7s
# 9773:	learn: 1.5623859	total: 9m 5s	remaining: 12.6s
# 9774:	learn: 1.5623842	total: 9m 5s	remaining: 12.6s
# 9775:	learn: 1.5623834	total: 9m 5s	remaining: 12.5s
# 9776:	learn: 1.5623809	total: 9m 5s	remaining: 12.4s
# 9777:	learn: 1.5623794	total: 9m 5s	remaining: 12.4s
# 9778:	learn: 1.5623767	total: 9m 5s	remaining: 12.3s
# 9779:	learn: 1.5623725	total: 9m 5s	remaining: 12.3s
# 9780:	learn: 1.5623706	total: 9m 5s	remaining: 12.2s
# 9781:	learn: 1.5623694	total: 9m 5s	remaining: 12.2s
# 9782:	learn: 1.5623676	total: 9m 5s	remaining: 12.1s
# 9783:	learn: 1.5623665	total: 9m 5s	remaining: 12s
# 9784:	learn: 1.5623639	total: 9m 5s	remaining: 12s
# 9785:	learn: 1.5623608	total: 9m 5s	remaining: 11.9s
# 9786:	learn: 1.5623595	total: 9m 5s	remaining: 11.9s
# 9787:	learn: 1.5623563	total: 9m 6s	remaining: 11.8s
# 9788:	learn: 1.5623554	total: 9m 6s	remaining: 11.8s
# 9789:	learn: 1.5623549	total: 9m 6s	remaining: 11.7s
# 9790:	learn: 1.5623515	total: 9m 6s	remaining: 11.7s
# 9791:	learn: 1.5623493	total: 9m 7s	remaining: 11.6s
# 9792:	learn: 1.5623477	total: 9m 7s	remaining: 11.6s
# 9793:	learn: 1.5623462	total: 9m 7s	remaining: 11.5s
# 9794:	learn: 1.5623437	total: 9m 7s	remaining: 11.5s
# 9795:	learn: 1.5623410	total: 9m 7s	remaining: 11.4s
# 9796:	learn: 1.5623396	total: 9m 7s	remaining: 11.4s
# 9797:	learn: 1.5623377	total: 9m 8s	remaining: 11.3s
# 9798:	learn: 1.5623366	total: 9m 8s	remaining: 11.2s
# 9799:	learn: 1.5623352	total: 9m 8s	remaining: 11.2s
# 9800:	learn: 1.5623346	total: 9m 8s	remaining: 11.1s
# 9801:	learn: 1.5623326	total: 9m 8s	remaining: 11.1s
# 9802:	learn: 1.5623304	total: 9m 8s	remaining: 11s
# 9803:	learn: 1.5623295	total: 9m 8s	remaining: 11s
# 9804:	learn: 1.5623277	total: 9m 8s	remaining: 10.9s
# 9805:	learn: 1.5623262	total: 9m 8s	remaining: 10.8s
# 9806:	learn: 1.5623249	total: 9m 8s	remaining: 10.8s
# 9807:	learn: 1.5623235	total: 9m 8s	remaining: 10.7s
# 9808:	learn: 1.5623209	total: 9m 8s	remaining: 10.7s
# 9809:	learn: 1.5623200	total: 9m 8s	remaining: 10.6s
# 9810:	learn: 1.5623188	total: 9m 9s	remaining: 10.6s
# 9811:	learn: 1.5623159	total: 9m 9s	remaining: 10.5s
# 9812:	learn: 1.5623152	total: 9m 9s	remaining: 10.5s
# 9813:	learn: 1.5623133	total: 9m 9s	remaining: 10.4s
# 9814:	learn: 1.5623121	total: 9m 9s	remaining: 10.4s
# 9815:	learn: 1.5623106	total: 9m 9s	remaining: 10.3s
# 9816:	learn: 1.5623091	total: 9m 9s	remaining: 10.2s
# 9817:	learn: 1.5623064	total: 9m 9s	remaining: 10.2s
# 9818:	learn: 1.5623049	total: 9m 9s	remaining: 10.1s
# 9819:	learn: 1.5623028	total: 9m 9s	remaining: 10.1s
# 9820:	learn: 1.5623028	total: 9m 9s	remaining: 10s
# 9821:	learn: 1.5623005	total: 9m 9s	remaining: 9.96s
# 9822:	learn: 1.5622995	total: 9m 9s	remaining: 9.91s
# 9823:	learn: 1.5622984	total: 9m 9s	remaining: 9.85s
# 9824:	learn: 1.5622975	total: 9m 9s	remaining: 9.79s
# 9825:	learn: 1.5622969	total: 9m 9s	remaining: 9.74s
# 9826:	learn: 1.5622964	total: 9m 10s	remaining: 9.68s
# 9827:	learn: 1.5622950	total: 9m 10s	remaining: 9.63s
# 9828:	learn: 1.5622938	total: 9m 10s	remaining: 9.57s
# 9829:	learn: 1.5622932	total: 9m 10s	remaining: 9.51s
# 9830:	learn: 1.5622901	total: 9m 10s	remaining: 9.46s
# 9831:	learn: 1.5622887	total: 9m 10s	remaining: 9.4s
# 9832:	learn: 1.5622862	total: 9m 10s	remaining: 9.35s
# 9833:	learn: 1.5622852	total: 9m 10s	remaining: 9.29s
# 9834:	learn: 1.5622849	total: 9m 10s	remaining: 9.23s
# 9835:	learn: 1.5622836	total: 9m 10s	remaining: 9.18s
# 9836:	learn: 1.5622825	total: 9m 10s	remaining: 9.12s
# 9837:	learn: 1.5622810	total: 9m 10s	remaining: 9.07s
# 9838:	learn: 1.5622802	total: 9m 10s	remaining: 9.01s
# 9839:	learn: 1.5622784	total: 9m 10s	remaining: 8.96s
# 9840:	learn: 1.5622768	total: 9m 11s	remaining: 8.9s
# 9841:	learn: 1.5622761	total: 9m 11s	remaining: 8.85s
# 9842:	learn: 1.5622761	total: 9m 11s	remaining: 8.79s
# 9843:	learn: 1.5622740	total: 9m 11s	remaining: 8.74s
# 9844:	learn: 1.5622729	total: 9m 11s	remaining: 8.68s
# 9845:	learn: 1.5622715	total: 9m 11s	remaining: 8.63s
# 9846:	learn: 1.5622707	total: 9m 11s	remaining: 8.57s
# 9847:	learn: 1.5622688	total: 9m 11s	remaining: 8.51s
# 9848:	learn: 1.5622671	total: 9m 11s	remaining: 8.46s
# 9849:	learn: 1.5622649	total: 9m 11s	remaining: 8.4s
# 9850:	learn: 1.5622634	total: 9m 11s	remaining: 8.34s
# 9851:	learn: 1.5622613	total: 9m 11s	remaining: 8.29s
# 9852:	learn: 1.5622594	total: 9m 11s	remaining: 8.23s
# 9853:	learn: 1.5622588	total: 9m 11s	remaining: 8.18s
# 9854:	learn: 1.5622585	total: 9m 11s	remaining: 8.12s
# 9855:	learn: 1.5622572	total: 9m 11s	remaining: 8.06s
# 9856:	learn: 1.5622540	total: 9m 11s	remaining: 8.01s
# 9857:	learn: 1.5622540	total: 9m 11s	remaining: 7.95s
# 9858:	learn: 1.5622513	total: 9m 12s	remaining: 7.9s
# 9859:	learn: 1.5622506	total: 9m 12s	remaining: 7.84s
# 9860:	learn: 1.5622495	total: 9m 12s	remaining: 7.79s
# 9861:	learn: 1.5622482	total: 9m 12s	remaining: 7.74s
# 9862:	learn: 1.5622468	total: 9m 13s	remaining: 7.68s
# 9863:	learn: 1.5622453	total: 9m 13s	remaining: 7.63s
# 9864:	learn: 1.5622446	total: 9m 13s	remaining: 7.57s
# 9865:	learn: 1.5622436	total: 9m 13s	remaining: 7.52s
# 9866:	learn: 1.5622407	total: 9m 13s	remaining: 7.46s
# 9867:	learn: 1.5622403	total: 9m 13s	remaining: 7.4s
# 9868:	learn: 1.5622372	total: 9m 13s	remaining: 7.35s
# 9869:	learn: 1.5622355	total: 9m 13s	remaining: 7.29s
# 9870:	learn: 1.5622351	total: 9m 13s	remaining: 7.24s
# 9871:	learn: 1.5622339	total: 9m 14s	remaining: 7.18s
# 9872:	learn: 1.5622318	total: 9m 14s	remaining: 7.13s
# 9873:	learn: 1.5622304	total: 9m 14s	remaining: 7.08s
# 9874:	learn: 1.5622285	total: 9m 14s	remaining: 7.02s
# 9875:	learn: 1.5622278	total: 9m 14s	remaining: 6.96s
# 9876:	learn: 1.5622252	total: 9m 14s	remaining: 6.91s
# 9877:	learn: 1.5622238	total: 9m 14s	remaining: 6.85s
# 9878:	learn: 1.5622219	total: 9m 14s	remaining: 6.79s
# 9879:	learn: 1.5622206	total: 9m 14s	remaining: 6.74s
# 9880:	learn: 1.5622186	total: 9m 14s	remaining: 6.68s
# 9881:	learn: 1.5622167	total: 9m 14s	remaining: 6.63s
# 9882:	learn: 1.5622153	total: 9m 14s	remaining: 6.57s
# 9883:	learn: 1.5622142	total: 9m 14s	remaining: 6.51s
# 9884:	learn: 1.5622126	total: 9m 15s	remaining: 6.46s
# 9885:	learn: 1.5622114	total: 9m 15s	remaining: 6.4s
# 9886:	learn: 1.5622090	total: 9m 15s	remaining: 6.34s
# 9887:	learn: 1.5622083	total: 9m 15s	remaining: 6.29s
# 9888:	learn: 1.5622067	total: 9m 15s	remaining: 6.23s
# 9889:	learn: 1.5622044	total: 9m 15s	remaining: 6.17s
# 9890:	learn: 1.5622029	total: 9m 15s	remaining: 6.12s
# 9891:	learn: 1.5622020	total: 9m 15s	remaining: 6.06s
# 9892:	learn: 1.5622006	total: 9m 15s	remaining: 6.01s
# 9893:	learn: 1.5621990	total: 9m 15s	remaining: 5.95s
# 9894:	learn: 1.5621968	total: 9m 15s	remaining: 5.89s
# 9895:	learn: 1.5621949	total: 9m 15s	remaining: 5.84s
# 9896:	learn: 1.5621920	total: 9m 15s	remaining: 5.78s
# 9897:	learn: 1.5621915	total: 9m 15s	remaining: 5.72s
# 9898:	learn: 1.5621891	total: 9m 15s	remaining: 5.67s
# 9899:	learn: 1.5621883	total: 9m 15s	remaining: 5.61s
# 9900:	learn: 1.5621859	total: 9m 15s	remaining: 5.56s
# 9901:	learn: 1.5621845	total: 9m 15s	remaining: 5.5s
# 9902:	learn: 1.5621836	total: 9m 15s	remaining: 5.44s
# 9903:	learn: 1.5621829	total: 9m 15s	remaining: 5.39s
# 9904:	learn: 1.5621820	total: 9m 16s	remaining: 5.33s
# 9905:	learn: 1.5621810	total: 9m 16s	remaining: 5.28s
# 9906:	learn: 1.5621788	total: 9m 16s	remaining: 5.22s
# 9907:	learn: 1.5621781	total: 9m 16s	remaining: 5.17s
# 9908:	learn: 1.5621770	total: 9m 16s	remaining: 5.11s
# 9909:	learn: 1.5621756	total: 9m 17s	remaining: 5.06s
# 9910:	learn: 1.5621748	total: 9m 17s	remaining: 5s
# 9911:	learn: 1.5621738	total: 9m 17s	remaining: 4.95s
# 9912:	learn: 1.5621693	total: 9m 17s	remaining: 4.89s
# 9913:	learn: 1.5621690	total: 9m 17s	remaining: 4.84s
# 9914:	learn: 1.5621676	total: 9m 18s	remaining: 4.79s
# 9915:	learn: 1.5621657	total: 9m 18s	remaining: 4.73s
# 9916:	learn: 1.5621649	total: 9m 18s	remaining: 4.67s
# 9917:	learn: 1.5621637	total: 9m 18s	remaining: 4.62s
# 9918:	learn: 1.5621630	total: 9m 18s	remaining: 4.56s
# 9919:	learn: 1.5621594	total: 9m 18s	remaining: 4.5s
# 9920:	learn: 1.5621581	total: 9m 18s	remaining: 4.45s
# 9921:	learn: 1.5621565	total: 9m 18s	remaining: 4.39s
# 9922:	learn: 1.5621554	total: 9m 18s	remaining: 4.33s
# 9923:	learn: 1.5621539	total: 9m 18s	remaining: 4.28s
# 9924:	learn: 1.5621512	total: 9m 18s	remaining: 4.22s
# 9925:	learn: 1.5621508	total: 9m 18s	remaining: 4.17s
# 9926:	learn: 1.5621487	total: 9m 18s	remaining: 4.11s
# 9927:	learn: 1.5621474	total: 9m 18s	remaining: 4.05s
# 9928:	learn: 1.5621458	total: 9m 18s	remaining: 4s
# 9929:	learn: 1.5621448	total: 9m 19s	remaining: 3.94s
# 9930:	learn: 1.5621442	total: 9m 19s	remaining: 3.88s
# 9931:	learn: 1.5621420	total: 9m 19s	remaining: 3.83s
# 9932:	learn: 1.5621406	total: 9m 19s	remaining: 3.77s
# 9933:	learn: 1.5621378	total: 9m 19s	remaining: 3.72s
# 9934:	learn: 1.5621359	total: 9m 19s	remaining: 3.66s
# 9935:	learn: 1.5621351	total: 9m 19s	remaining: 3.6s
# 9936:	learn: 1.5621343	total: 9m 19s	remaining: 3.55s
# 9937:	learn: 1.5621330	total: 9m 19s	remaining: 3.49s
# 9938:	learn: 1.5621311	total: 9m 19s	remaining: 3.43s
# 9939:	learn: 1.5621282	total: 9m 19s	remaining: 3.38s
# 9940:	learn: 1.5621264	total: 9m 19s	remaining: 3.32s
# 9941:	learn: 1.5621244	total: 9m 19s	remaining: 3.27s
# 9942:	learn: 1.5621240	total: 9m 19s	remaining: 3.21s
# 9943:	learn: 1.5621229	total: 9m 20s	remaining: 3.15s
# 9944:	learn: 1.5621213	total: 9m 20s	remaining: 3.1s
# 9945:	learn: 1.5621207	total: 9m 20s	remaining: 3.04s
# 9946:	learn: 1.5621179	total: 9m 20s	remaining: 2.99s
# 9947:	learn: 1.5621159	total: 9m 20s	remaining: 2.93s
# 9948:	learn: 1.5621135	total: 9m 21s	remaining: 2.88s
# 9949:	learn: 1.5621115	total: 9m 21s	remaining: 2.82s
# 9950:	learn: 1.5621110	total: 9m 21s	remaining: 2.76s
# 9951:	learn: 1.5621103	total: 9m 21s	remaining: 2.71s
# 9952:	learn: 1.5621086	total: 9m 21s	remaining: 2.65s
# 9953:	learn: 1.5621070	total: 9m 22s	remaining: 2.6s
# 9954:	learn: 1.5621056	total: 9m 22s	remaining: 2.54s
# 9955:	learn: 1.5621047	total: 9m 22s	remaining: 2.48s
# 9956:	learn: 1.5621027	total: 9m 22s	remaining: 2.43s
# 9957:	learn: 1.5621012	total: 9m 22s	remaining: 2.37s
# 9958:	learn: 1.5620996	total: 9m 22s	remaining: 2.31s
# 9959:	learn: 1.5620989	total: 9m 22s	remaining: 2.26s
# 9960:	learn: 1.5620965	total: 9m 22s	remaining: 2.2s
# 9961:	learn: 1.5620959	total: 9m 22s	remaining: 2.15s
# 9962:	learn: 1.5620939	total: 9m 22s	remaining: 2.09s
# 9963:	learn: 1.5620913	total: 9m 22s	remaining: 2.03s
# 9964:	learn: 1.5620882	total: 9m 22s	remaining: 1.98s
# 9965:	learn: 1.5620858	total: 9m 22s	remaining: 1.92s
# 9966:	learn: 1.5620856	total: 9m 22s	remaining: 1.86s
# 9967:	learn: 1.5620837	total: 9m 22s	remaining: 1.81s
# 9968:	learn: 1.5620823	total: 9m 23s	remaining: 1.75s
# 9969:	learn: 1.5620808	total: 9m 23s	remaining: 1.69s
# 9970:	learn: 1.5620779	total: 9m 23s	remaining: 1.64s
# 9971:	learn: 1.5620772	total: 9m 23s	remaining: 1.58s
# 9972:	learn: 1.5620762	total: 9m 23s	remaining: 1.52s
# 9973:	learn: 1.5620756	total: 9m 23s	remaining: 1.47s
# 9974:	learn: 1.5620736	total: 9m 23s	remaining: 1.41s
# 9975:	learn: 1.5620710	total: 9m 23s	remaining: 1.35s
# 9976:	learn: 1.5620689	total: 9m 23s	remaining: 1.3s
# 9977:	learn: 1.5620681	total: 9m 23s	remaining: 1.24s
# 9978:	learn: 1.5620670	total: 9m 23s	remaining: 1.19s
# 9979:	learn: 1.5620664	total: 9m 24s	remaining: 1.13s
# 9980:	learn: 1.5620640	total: 9m 24s	remaining: 1.07s
# 9981:	learn: 1.5620633	total: 9m 24s	remaining: 1.02s
# 9982:	learn: 1.5620633	total: 9m 24s	remaining: 961ms
# 9983:	learn: 1.5620623	total: 9m 24s	remaining: 905ms
# 9984:	learn: 1.5620619	total: 9m 24s	remaining: 848ms
# 9985:	learn: 1.5620615	total: 9m 24s	remaining: 792ms
# 9986:	learn: 1.5620606	total: 9m 24s	remaining: 735ms
# 9987:	learn: 1.5620589	total: 9m 25s	remaining: 679ms
# 9988:	learn: 1.5620559	total: 9m 25s	remaining: 622ms
# 9989:	learn: 1.5620545	total: 9m 25s	remaining: 566ms
# 9990:	learn: 1.5620535	total: 9m 25s	remaining: 510ms
# 9991:	learn: 1.5620519	total: 9m 25s	remaining: 453ms
# 9992:	learn: 1.5620503	total: 9m 26s	remaining: 397ms
# 9993:	learn: 1.5620475	total: 9m 26s	remaining: 340ms
# 9994:	learn: 1.5620443	total: 9m 26s	remaining: 283ms
# 9995:	learn: 1.5620421	total: 9m 26s	remaining: 227ms
# 9996:	learn: 1.5620404	total: 9m 26s	remaining: 170ms
# 9997:	learn: 1.5620391	total: 9m 26s	remaining: 113ms
# 9998:	learn: 1.5620375	total: 9m 26s	remaining: 56.7ms
# 9999:	learn: 1.5620360	total: 9m 26s	remaining: 0us

# %% [markdown]
# #### Preve para os dados de teste

# %%
# test_data = targets.merge(content_auxiliar[["ItemId"] + columns_to_float + variaveis_categoricas], on="ItemId")
# test_data.set_index(["UserId", "ItemId"], inplace=True)

# %%
previsao_test = model.predict(target_prediction)

# %%
target_prediction["Rating"] = previsao_test

# %%
# target_prediction = test_data.reset_index()[["UserId", "ItemId"]]

# %% [markdown]
# ### Salva a previsao

# %%
target_prediction = target_prediction.sort_values(["UserId", "Rating"], ascending=[True, False])

# %%
# target_prediction.to_csv("submissoes/catboost_versao_1.csv", index=False)
target_prediction.to_csv("submissoes/lightfm_catboost_versao_1.csv", index=False)

# %%
target_prediction = target_prediction.drop(columns="Rating")

# %%
# target_prediction.to_csv("submissoes/catboost_versao_1_sem_rating.csv", index=False)
target_prediction.to_csv("submissoes/lightfm_catboost_versao_1_sem_rating.csv", index=False)

# %%
target_prediction.reset_index()[["UserId", "ItemId"]].to_csv("submissoes/lightfm_catboost_versao_1_sem_rating.csv", index=False)
